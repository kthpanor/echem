# %% [markdown]
# # Exercises
#
# In this exercise we will look at how substitution affects the vibrational frequencies, IR, and Raman spectra.

# %%
# import section
import veloxchem as vlx
import py3Dmol as p3d
from veloxchem.veloxchemlib import bohr_in_angstroms
from matplotlib import pyplot as plt
import numpy as np
from veloxchem.veloxchemlib import bohr_in_angstroms

basis_set_label = "6-31G"

# %%
# define molecules and basis sets
ethene_xyz = """6
 ethene
 C          0.000000    -0.663984   0.000000
 C          0.000000     0.663984   0.000000
 H          0.919796    -1.223061   0.000000
 H         -0.919796    -1.223061   0.000000
 H          0.919796     1.223061   0.000000
 H         -0.919796     1.223061   0.000000
"""
ethene = vlx.Molecule.from_xyz_string(ethene_xyz)
ethene_basis = vlx.MolecularBasis.read(ethene, basis_set_label)

# %%
fluoroethene_xyz = """6
fluoroethene
 C          0.000000    -0.663984   0.000000
 C          0.000000     0.663984   0.000000
 F         1.519796    -1.223061   0.000000
 H         -0.919796    -1.223061   0.000000
 H          0.919796     1.223061   0.000000
 H         -0.919796     1.223061   0.000000
 """
fluoroethene = vlx.Molecule.from_xyz_string(fluoroethene_xyz)
fluoroethene_basis = vlx.MolecularBasis.read(fluoroethene, basis_set_label)

# %%
chloroethene_xyz = """6
chloroethene
 C          0.000000    -0.663984   0.000000
 C          0.000000     0.663984   0.000000
 Cl         1.519796    -1.223061   0.000000
 H         -0.919796    -1.223061   0.000000
 H          0.919796     1.223061   0.000000
 H         -0.919796     1.223061   0.000000
 """
chloroethene = vlx.Molecule.from_xyz_string(chloroethene_xyz)
chloroethene_basis = vlx.MolecularBasis.read(chloroethene, basis_set_label)

# %%
# to view the molecules
view = p3d.view(linked=True, viewergrid=(1,3),width=700,height=200)
view.addModel(ethene_xyz, 'xyz', viewer=(0,0))
view.addModel(fluoroethene_xyz, 'xyz', viewer=(0,1))
view.addModel(chloroethene_xyz, 'xyz', viewer=(0,2))
view.setStyle({'stick': {}})
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_16513962901800735"  style="position: relative; width: 700px; height: 200px">
#         <p id="3dmolwarning_16513962901800735" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16513962901800735 = null;
# var warn = document.getElementById("3dmolwarning_16513962901800735");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_16513962901800735 = null;
# viewergrid_16513962901800735 = $3Dmol.createViewerGrid($("#3dmolviewer_16513962901800735"),{rows: 1, cols: 3, control_all: true},{backgroundColor:"white"});
# viewer_16513962901800735 = viewergrid_16513962901800735[0][0];
# viewergrid_16513962901800735[0][0].zoomTo();viewergrid_16513962901800735[0][1].zoomTo();viewergrid_16513962901800735[0][2].zoomTo();	viewergrid_16513962901800735[0][0].addModel("6\n ethene\n C          0.000000    -0.663984   0.000000\n C          0.000000     0.663984   0.000000\n H          0.919796    -1.223061   0.000000\n H         -0.919796    -1.223061   0.000000\n H          0.919796     1.223061   0.000000\n H         -0.919796     1.223061   0.000000\n","xyz");
# 	viewergrid_16513962901800735[0][1].addModel("6\nfluoroethene\n C          0.000000    -0.663984   0.000000\n C          0.000000     0.663984   0.000000\n F         1.519796    -1.223061   0.000000\n H         -0.919796    -1.223061   0.000000\n H          0.919796     1.223061   0.000000\n H         -0.919796     1.223061   0.000000\n ","xyz");
# 	viewergrid_16513962901800735[0][2].addModel("6\nchloroethene\n C          0.000000    -0.663984   0.000000\n C          0.000000     0.663984   0.000000\n Cl         1.519796    -1.223061   0.000000\n H         -0.919796    -1.223061   0.000000\n H          0.919796     1.223061   0.000000\n H         -0.919796     1.223061   0.000000\n ","xyz");
# 	viewergrid_16513962901800735[0][0].setStyle({"stick": {}});
# 	viewergrid_16513962901800735[0][1].setStyle({"stick": {}});
# 	viewergrid_16513962901800735[0][2].setStyle({"stick": {}});
# 	viewergrid_16513962901800735[0][0].zoomTo();
# 	viewergrid_16513962901800735[0][1].zoomTo();
# 	viewergrid_16513962901800735[0][2].zoomTo();
# viewergrid_16513962901800735[0][2].render();
# viewergrid_16513962901800735[0][1].render();
# viewergrid_16513962901800735[0][0].render();
# });
# </script>

# %% [markdown]
# ## SCF geometry optimization
# Before we can calculate the vibrational spectra, we first must optimize the geometries.

# %%
# Settings for SCF and gradient drivers
scf_settings = {'conv_thresh':1e-6}
method_settings = {}

# %%
# Run SCF for ethene
ethene_scfdrv = vlx.ScfRestrictedDriver()
ethene_scfdrv.update_settings(scf_settings, method_settings)
ethene_scfdrv.ostream.state = False 
ethene_scfdrv.compute(ethene, ethene_basis)

# Run SCF for fluoroethene
fluoroethene_scfdrv = vlx.ScfRestrictedDriver()
fluoroethene_scfdrv.update_settings(scf_settings, method_settings)
fluoroethene_scfdrv.ostream.state = False 
fluoroethene_scfdrv.compute(fluoroethene, fluoroethene_basis)

# Run SCF for chloroethene
chloroethene_scfdrv = vlx.ScfRestrictedDriver()
chloroethene_scfdrv.update_settings(scf_settings, method_settings)
chloroethene_scfdrv.ostream.state = False 
chloroethene_scfdrv.compute(chloroethene, chloroethene_basis)

# %%
# Set up the gradient and optimization dirvers:
ethene_grad_drv = vlx.ScfGradientDriver(ethene_scfdrv)
ethene_opt_drv = vlx.OptimizationDriver(ethene_grad_drv)

fluoroethene_grad_drv = vlx.ScfGradientDriver(fluoroethene_scfdrv)
fluoroethene_opt_drv = vlx.OptimizationDriver(fluoroethene_grad_drv)

chloroethene_grad_drv = vlx.ScfGradientDriver(chloroethene_scfdrv)
chloroethene_opt_drv = vlx.OptimizationDriver(chloroethene_grad_drv)

# %%
# Either optimize the geometries
opt_ethene = ethene_opt_drv.compute(ethene, ethene_basis)

# %%
fluoroethene_opt_drv.ostream.state = True # to enable printout
opt_fluoroethene = fluoroethene_opt_drv.compute(fluoroethene, fluoroethene_basis)
# Out:
#
#                                                 Optimization Driver Setup
#                                                ===========================
#
#                                      Coordinate System       :    TRIC
#                                      Constraints             :    No
#                                      Max. Number of Steps    :    300
#                                      Transition State        :    No
#                                      Hessian                 :    never
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.7870796714 a.u.
# * Info *   Gradient : 5.502126e-02 a.u. (RMS)
# * Info *              1.006969e-01 a.u. (Max)
# * Info *   Time     : 20.13 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8239348117 a.u.
# * Info *   Gradient : 1.936097e-02 a.u. (RMS)
# * Info *              3.608572e-02 a.u. (Max)
# * Info *   Time     : 25.23 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8247093532 a.u.
# * Info *   Gradient : 1.466177e-02 a.u. (RMS)
# * Info *              2.630091e-02 a.u. (Max)
# * Info *   Time     : 25.23 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8253293530 a.u.
# * Info *   Gradient : 1.800204e-02 a.u. (RMS)
# * Info *              2.954313e-02 a.u. (Max)
# * Info *   Time     : 26.52 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8274633162 a.u.
# * Info *   Gradient : 3.690283e-03 a.u. (RMS)
# * Info *              6.293050e-03 a.u. (Max)
# * Info *   Time     : 25.96 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8275171910 a.u.
# * Info *   Gradient : 2.227141e-03 a.u. (RMS)
# * Info *              4.313403e-03 a.u. (Max)
# * Info *   Time     : 25.89 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8275330208 a.u.
# * Info *   Gradient : 6.451043e-04 a.u. (RMS)
# * Info *              1.008072e-03 a.u. (Max)
# * Info *   Time     : 24.89 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8275349381 a.u.
# * Info *   Gradient : 2.121866e-04 a.u. (RMS)
# * Info *              3.039704e-04 a.u. (Max)
# * Info *   Time     : 25.87 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -176.8275354102 a.u.
# * Info *   Gradient : 6.607244e-05 a.u. (RMS)
# * Info *              1.194725e-04 a.u. (Max)
# * Info *   Time     : 25.51 sec
#
# * Info * Geometry optimization completed.
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C           0.173697674376       -0.612778180441        0.000000008537
#                            C           0.061892932724        0.692644588940        0.000000002694
#                            F           1.408302557093       -1.223896918251       -0.000000007596
#                            H          -0.615724067231       -1.330913597271        0.000000001503
#                            H           0.923684071510        1.328304965030       -0.000000001624
#                            H          -0.905878918562        1.149986893120        0.000000003750
#
#
#                                              Summary of Geometry Optimization
#                                             ==================================
#
#                   Opt.Step       Energy (a.u.)       Energy Change (a.u.)       Displacement (RMS, Max)
#                   -------------------------------------------------------------------------------------
#                       0        -176.787079671390        0.000000000000         0.000e+00      0.000e+00
#                       1        -176.823934811733       -0.036855140343         1.065e-01      1.993e-01
#                       2        -176.824709353241       -0.000774541508         9.897e-02      1.545e-01
#                       3        -176.825329353047       -0.000619999806         4.958e-02      9.073e-02
#                       4        -176.827463316196       -0.002133963149         2.703e-02      4.099e-02
#                       5        -176.827517191029       -0.000053874833         7.333e-03      9.886e-03
#                       6        -176.827533020786       -0.000015829757         2.513e-03      3.231e-03
#                       7        -176.827534938133       -0.000001917347         1.452e-03      2.580e-03
#                       8        -176.827535410182       -0.000000472049         7.218e-04      1.087e-03
#
#
#                                               Statistical Deviation between
#                                          Optimized Geometry and Initial Geometry
#                                         =========================================
#
#                                Internal Coord.        RMS deviation         Max. deviation
#                                -----------------------------------------------------------
#                                   Bonds               0.109 Angstrom        0.242 Angstrom
#                                   Angles              9.124 degree         17.139 degree
#                                   Dihedrals           0.000 degree          0.000 degree
#
#                                     *** Time spent in Optimization Driver: 225.70 sec

# %%
chloroethene_opt_drv.ostream.state = True
opt_chloroethene = chloroethene_opt_drv.compute(chloroethene, chloroethene_basis)
# Out:
#
#                                                 Optimization Driver Setup
#                                                ===========================
#
#                                      Coordinate System       :    TRIC
#                                      Constraints             :    No
#                                      Max. Number of Steps    :    300
#                                      Transition State        :    No
#                                      Hessian                 :    never
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8475285019 a.u.
# * Info *   Gradient : 8.047900e-02 a.u. (RMS)
# * Info *              1.443314e-01 a.u. (Max)
# * Info *   Time     : 42.47 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8698780379 a.u.
# * Info *   Gradient : 5.247945e-02 a.u. (RMS)
# * Info *              1.016471e-01 a.u. (Max)
# * Info *   Time     : 41.90 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8812437705 a.u.
# * Info *   Gradient : 9.241227e-03 a.u. (RMS)
# * Info *              1.611692e-02 a.u. (Max)
# * Info *   Time     : 40.82 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8814869363 a.u.
# * Info *   Gradient : 6.191897e-03 a.u. (RMS)
# * Info *              9.270803e-03 a.u. (Max)
# * Info *   Time     : 41.91 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8821274964 a.u.
# * Info *   Gradient : 2.100207e-03 a.u. (RMS)
# * Info *              2.899217e-03 a.u. (Max)
# * Info *   Time     : 41.46 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8822116136 a.u.
# * Info *   Gradient : 2.479726e-04 a.u. (RMS)
# * Info *              4.164576e-04 a.u. (Max)
# * Info *   Time     : 41.96 sec
#
# * Info * Computing energy and gradient...
# * Info *   Energy   : -536.8822123834 a.u.
# * Info *   Gradient : 6.544576e-05 a.u. (RMS)
# * Info *              9.704660e-05 a.u. (Max)
# * Info *   Time     : 44.17 sec
#
# * Info * Geometry optimization completed.
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C           0.011585559854       -0.577580790418       -0.000000023052
#                            C          -0.026843945364        0.733720843719        0.000000011838
#                            Cl          1.563971239660       -1.502567568841       -0.000000020545
#                            H          -0.832943584375       -1.229620922158       -0.000000039531
#                            H           0.857894604794        1.337707527889        0.000000040545
#                            H          -0.973663026596        1.238343490162        0.000000023430
#
#
#                                              Summary of Geometry Optimization
#                                             ==================================
#
#                   Opt.Step       Energy (a.u.)       Energy Change (a.u.)       Displacement (RMS, Max)
#                   -------------------------------------------------------------------------------------
#                       0        -536.847528501891        0.000000000000         0.000e+00      0.000e+00
#                       1        -536.869878037922       -0.022349536031         1.002e-01      1.888e-01
#                       2        -536.881243770513       -0.011365732591         4.595e-02      6.474e-02
#                       3        -536.881486936267       -0.000243165754         4.443e-02      6.754e-02
#                       4        -536.882127496416       -0.000640560149         2.218e-02      4.225e-02
#                       5        -536.882211613577       -0.000084117161         1.104e-02      1.914e-02
#                       6        -536.882212383404       -0.000000769826         1.005e-03      1.770e-03
#
#
#                                               Statistical Deviation between
#                                          Optimized Geometry and Initial Geometry
#                                         =========================================
#
#                                Internal Coord.        RMS deviation         Max. deviation
#                                -----------------------------------------------------------
#                                   Bonds               0.084 Angstrom        0.188 Angstrom
#                                   Angles              8.840 degree         16.970 degree
#                                   Dihedrals           0.000 degree          0.000 degree
#
#                                     *** Time spent in Optimization Driver: 295.27 sec

# %%
# Get optimized coordinates
def get_xyz(molecule):
    natm = molecule.number_of_atoms()
    elements = molecule.get_labels()
    coords = molecule.get_coordinates() * bohr_in_angstroms()
    txt = "%d\n\n" % natm
    for i in range(natm):
        txt += elements[i] + " %15.7f %15.7f %15.7f\n" % (coords[i,0], coords[i,1], coords[i,2])
    return txt

# %%
opt_ethene_xyz = get_xyz(opt_ethene)
opt_fluoroethene_xyz = get_xyz(opt_fluoroethene)
opt_chloroethene_xyz = get_xyz(opt_chloroethene)

# %% [markdown]
# ```python
# # Or read optimized geometries from file:
# opt_ethene_xyz = open("../xyz/ir_raman/opt_ethene.xyz", "r").read() # read optimized geometry from file
# opt_fluoroethene_xyz = open("../xyz/ir_raman/opt_fluoroethene.xyz", "r").read() # read optimized geometry from file
# opt_chloroethene_xyz = open("../xyz/ir_raman/opt_chloroethene.xyz", "r").read() # read optimized geometry from file
#
# opt_ethene = vlx.Molecule.from_xyz_string(opt_ethene_xyz)
# ethene_basis = vlx.MolecularBasis.read(opt_ethene, basis_set_label)
#
# opt_fluoroethene = vlx.Molecule.from_xyz_string(opt_fluoroethene_xyz)
# fluoroethene_basis = vlx.MolecularBasis.read(opt_fluoroethene, basis_set_label)
#
# opt_chloroethene = vlx.Molecule.from_xyz_string(opt_chloroethene_xyz)
# chloroethene_basis = vlx.MolecularBasis.read(opt_chloroethene, basis_set_label)
# ```

# %%
# Visualize the optimized molecular structures
view = p3d.view(linked=True, viewergrid=(1,3),width=700,height=200)
view.addModel(opt_ethene_xyz, 'xyz', viewer=(0,0))
view.addModel(opt_fluoroethene_xyz, 'xyz', viewer=(0,1))
view.addModel(opt_chloroethene_xyz, 'xyz', viewer=(0,2))
view.setStyle({'stick': {}})
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_1651397822720927"  style="position: relative; width: 700px; height: 200px">
#         <p id="3dmolwarning_1651397822720927" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1651397822720927 = null;
# var warn = document.getElementById("3dmolwarning_1651397822720927");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_1651397822720927 = null;
# viewergrid_1651397822720927 = $3Dmol.createViewerGrid($("#3dmolviewer_1651397822720927"),{rows: 1, cols: 3, control_all: true},{backgroundColor:"white"});
# viewer_1651397822720927 = viewergrid_1651397822720927[0][0];
# viewergrid_1651397822720927[0][0].zoomTo();viewergrid_1651397822720927[0][1].zoomTo();viewergrid_1651397822720927[0][2].zoomTo();	viewergrid_1651397822720927[0][0].addModel("6\n\nC       0.0000322      -0.6609981       0.0000000\nC       0.0000322       0.6609981      -0.0000000\nH       0.9114507      -1.2291287      -0.0000000\nH      -0.9114829      -1.2289599       0.0000000\nH       0.9114507       1.2291287      -0.0000000\nH      -0.9114829       1.2289599      -0.0000000\n","xyz");
# 	viewergrid_1651397822720927[0][1].addModel("6\n\nC       0.1736977      -0.6127782       0.0000000\nC       0.0618929       0.6926446       0.0000000\nF       1.4083026      -1.2238969      -0.0000000\nH      -0.6157241      -1.3309136       0.0000000\nH       0.9236841       1.3283050      -0.0000000\nH      -0.9058789       1.1499869       0.0000000\n","xyz");
# 	viewergrid_1651397822720927[0][2].addModel("6\n\nC       0.0115856      -0.5775808      -0.0000000\nC      -0.0268439       0.7337208       0.0000000\nCl       1.5639712      -1.5025676      -0.0000000\nH      -0.8329436      -1.2296209      -0.0000000\nH       0.8578946       1.3377075       0.0000000\nH      -0.9736630       1.2383435       0.0000000\n","xyz");
# 	viewergrid_1651397822720927[0][0].setStyle({"stick": {}});
# 	viewergrid_1651397822720927[0][1].setStyle({"stick": {}});
# 	viewergrid_1651397822720927[0][2].setStyle({"stick": {}});
# 	viewergrid_1651397822720927[0][0].zoomTo();
# 	viewergrid_1651397822720927[0][1].zoomTo();
# 	viewergrid_1651397822720927[0][2].zoomTo();
# viewergrid_1651397822720927[0][2].render();
# viewergrid_1651397822720927[0][1].render();
# viewergrid_1651397822720927[0][0].render();
# });
# </script>

# %%
# Compute SCF with the optimized geometries of all molecules
ethene_scfdrv.compute(opt_ethene, ethene_basis)
fluoroethene_scfdrv.compute(opt_fluoroethene, fluoroethene_basis)
chloroethene_scfdrv.compute(opt_chloroethene, chloroethene_basis)
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Scheme            : Cauchy Schwarz + Density
#                    ERI Screening Mode              : Dynamic
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Nuclear repulsion energy: 67.2312635228 a.u.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
# * Info * SAD initial guess computed in 0.00 sec.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -176.827527115004 a.u. Time: 0.27 sec.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.01 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1      -176.827535221004    0.0000000000      0.00085110      0.00010787      0.00000000
#                   2      -176.827535359195   -0.0000001382      0.00053052      0.00006654      0.00049743
#                   3      -176.827535409241   -0.0000000500      0.00005463      0.00000732      0.00037449
#                   4      -176.827535410093   -0.0000000009      0.00002050      0.00000192      0.00003895
#                   5      -176.827535410179   -0.0000000001      0.00000350      0.00000054      0.00001430
#                   6      -176.827535410181   -0.0000000000      0.00000213      0.00000024      0.00000248
#                   7      -176.827535410182   -0.0000000000      0.00000032      0.00000005      0.00000141
#
#                *** SCF converged in 7 iterations. Time: 0.41 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :     -176.8275354102 a.u.
#                Electronic Energy                  :     -244.0587989329 a.u.
#                Nuclear Repulsion Energy           :       67.2312635228 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000003187 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1.0
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                  Spin Restricted Orbitals
#                                                  ------------------------
#
#                Molecular Orbital No.   8:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.67348 a.u.
#                (   1 C   1p+1:    -0.18) (   1 C   1p-1:     0.23) (   2 C   3s  :    -0.15)
#                (   2 C   1p-1:    -0.31) (   3 F   1p+1:     0.39) (   3 F   2p+1:     0.28)
#                (   5 H   1s  :    -0.18)
#
#                Molecular Orbital No.   9:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.66583 a.u.
#                (   1 C   1p0 :     0.16) (   3 F   1p0 :     0.62) (   3 F   2p0 :     0.44)
#
#                Molecular Orbital No.  10:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.58623 a.u.
#                (   1 C   1p-1:     0.19) (   2 C   1p+1:     0.31) (   2 C   1p-1:    -0.18)
#                (   3 F   1p-1:    -0.44) (   3 F   2p-1:    -0.32) (   6 H   1s  :    -0.22)
#                (   6 H   2s  :    -0.18)
#
#                Molecular Orbital No.  11:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.55928 a.u.
#                (   1 C   1p+1:     0.18) (   1 C   1p-1:     0.22) (   2 C   1p+1:    -0.25)
#                (   2 C   1p-1:    -0.20) (   2 C   2p+1:    -0.16) (   3 F   1p+1:    -0.28)
#                (   3 F   1p-1:    -0.18) (   3 F   2p+1:    -0.22) (   4 H   1s  :    -0.22)
#                (   4 H   2s  :    -0.18) (   5 H   1s  :    -0.20) (   5 H   2s  :    -0.15)
#
#                Molecular Orbital No.  12:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.39129 a.u.
#                (   1 C   1p0 :    -0.38) (   1 C   2p0 :    -0.26) (   2 C   1p0 :    -0.39)
#                (   2 C   2p0 :    -0.32) (   3 F   1p0 :     0.22) (   3 F   2p0 :     0.21)
#
#                Molecular Orbital No.  13:
#                --------------------------
#                Occupation: 0.000 Energy:    0
#                (   4 H   2s  :    -1.07) (   5 H   2s  :     1.65) (   6 H   2s  :     0.93)
#
#                Molecular Orbital No.  21:
#                --------------------------
#                Occupation: 0.000 Energy:    0.36611 a.u.
#                (   1 C   3s  :     0.50) (   1 C   1p+1:    -0.24) (   1 C   2p+1:    -1.65)
#                (   2 C   1p+1:     0.30) (   2 C   2p+1:     1.95) (   2 C   2p-1:     0.17)
#                (   3 Cl  3s  :     0.18) (   3 Cl  4s  :     0.54) (   3 Cl  3p+1:    -0.56)
#                (   3 Cl  3p-1:     0.44) (   4 H   2s  :    -1.59) (   5 H   2s  :    -1.81)
#                (   6 H   2s  :     1.72)

# %% [markdown]
# ## Hessians
#
# Now, let's calculate the IR and Raman spectra for these optimized geometries

# %%
# Settings for Hessian calculation
hessian_settings = {'do_raman': 'yes', 'print_depolarization_ratio':'no'}

# %%
# Create Hessian driver and update settings
ethene_hessian_drv = vlx.scfhessiandriver.ScfHessianDriver(ethene_scfdrv)
ethene_hessian_drv.update_settings(method_settings, hessian_settings)

fluoroethene_hessian_drv = vlx.scfhessiandriver.ScfHessianDriver(fluoroethene_scfdrv)
fluoroethene_hessian_drv.update_settings(method_settings, hessian_settings)

chloroethene_hessian_drv = vlx.scfhessiandriver.ScfHessianDriver(chloroethene_scfdrv)
chloroethene_hessian_drv.update_settings(method_settings, hessian_settings)

# %%
# Compute the Hessians:
ethene_hessian_drv.compute(ethene, ethene_basis)
fluoroethene_hessian_drv.compute(fluoroethene, fluoroethene_basis)
chloroethene_hessian_drv.compute(chloroethene, chloroethene_basis)
# Out:
#
#                                                     SCF Hessian Driver
#                                                    ====================
#
#                                   *** Time spent in Hessian calculation: 284.38 sec ***
#
#
#
#                                                     SCF Hessian Driver
#                                                    ====================
#
#                                   *** Time spent in Hessian calculation: 504.05 sec ***
#
#
#
#                                                     SCF Hessian Driver
#                                                    ====================
#
#                                   *** Time spent in Hessian calculation: 874.67 sec ***

# %% [markdown]
# ```python
# # Or read them from file:
# import h5py
#
# fname = '../h5files/ir_raman/ethenes.h5'
# hf = h5py.File(fname, "r")
#
# labels = ['ethene', 'fluoroethene', 'chloroethene']
#
# i = 0
# for driver in [ethene_hessian_drv, fluoroethene_hessian_drv, chloroethene_hessian_drv]:
#     label = labels[i]
#
#     driver.hessian = np.array(hf.get(label + '_hessian'))
#     driver.dipole_gradient = np.array( hf.get(label + '_dipolegrad'))
#     driver.polarizability_gradient = np.array(hf.get(label + '_polgrad'))
#
#     i += 1
#
# hf.close()
# ```

# %%
# Broadening function
def add_broadening(list_ex_energy, list_osci_strength, line_profile='Lorentzian', line_param=10, step=10):
        x_min = np.amin(list_ex_energy) - 50
        x_max = np.amax(list_ex_energy) + 50
        x = np.arange(x_min, x_max, step)
        y = np.zeros((len(x)))
        #print(x)
        #print(y)

        # go through the frames and calculate the spectrum for each frame
        for xp in range(len(x)):
            for e, f in zip(list_ex_energy, list_osci_strength):
                if line_profile == 'Gaussian':
                    y[xp] += f * np.exp(-(
                        (e - x[xp]) / line_param)**2)
                elif line_profile == 'Lorentzian':
                    y[xp] += 0.5 * line_param * f / (np.pi * (
                        (x[xp] - e)**2 + 0.25 * line_param**2))
        return x, y

        
# To animate the normal mode we will need both the geometry and the displacements 
def get_normal_mode(molecule, normal_mode):
    elements = molecule.get_labels()
    coords = molecule.get_coordinates() * bohr_in_angstroms() # To transform from au to A
    natm = molecule.number_of_atoms()
    vib_xyz = "%d\n\n" % natm
    nm = normal_mode.reshape(natm, 3)
    for i in range(natm):
        # add coordinates:
        vib_xyz += elements[i] + " %15.7f %15.7f %15.7f " % (coords[i,0], coords[i,1], coords[i,2])
        # add displacements:
        vib_xyz += "%15.7f %15.7f %15.7f\n" % (nm[i,0], nm[i,1], nm[i,2])
    return vib_xyz

# %% [markdown]
# ## Vibrational analysis
#
# To get a summary of the vibrational analysis, one simply needs to run the following command:

# %%
# Run for all molecules
ethene_hessian_drv.vibrational_analysis(opt_ethene)
fluoroethene_hessian_drv.vibrational_analysis(opt_fluoroethene)
chloroethene_hessian_drv.vibrational_analysis(opt_chloroethene)
# Out:
#                                                    Vibrational Analysis
#                                                   ======================
#
#                  Harmonic frequencies (in cm**-1), force constants (in mdyne/A), reduced masses (in amu),
#                           IR intensities (in km/mol), Raman scattering activities (in A**4/amu),
#                                          and Cartesian normal mode displacements.
#
#
#   Index:                        1                              2                              3
#   Frequency:                 945.00                         1121.72                        1156.61
#   Force constant:            0.5486                         0.8606                         1.1972
#   Reduced mass:              1.0426                         1.1608                         1.5189
#   IR intensity:              0.8763                        142.4382                        0.0000
#   Raman activ.:              0.0000                         0.0000                         6.1003
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C              0.0397   -0.0000   -0.0000  | -0.0000   -0.0000   -0.0833  | -0.0000    0.0000   -0.1524  |
#   2 C              0.0397   -0.0000    0.0000  | -0.0000    0.0000   -0.0833  |  0.0000   -0.0000    0.1524  |
#   3 H             -0.2363   -0.4397   -0.0000  |  0.0000    0.0000    0.4965  |  0.0000    0.0000    0.4883  |
#   4 H             -0.2363    0.4397    0.0000  |  0.0000   -0.0000    0.4965  |  0.0000   -0.0000    0.4882  |
#   5 H             -0.2363    0.4397    0.0000  |  0.0000   -0.0000    0.4965  |  0.0000   -0.0000   -0.4883  |
#   6 H             -0.2363   -0.4397   -0.0000  |  0.0000    0.0000    0.4965  |  0.0000    0.0000   -0.4882  |
#
#   Index:                        4                              5                              6
#   Frequency:                 1163.92                        1387.82                        1503.60
#   Force constant:            0.8045                         1.7231                         1.7306
#   Reduced mass:              1.0080                         1.5184                         1.2992
#   IR intensity:              0.0000                         0.0000                         0.0000
#   Raman activ.:              0.0000                         1.4038                         51.5970
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.0000    0.0000    0.0000  | -0.1523   -0.0000    0.0000  | -0.0000    0.1150    0.0000  |
#   2 C             -0.0000    0.0000    0.0000  |  0.1523    0.0000   -0.0000  |  0.0000   -0.1150   -0.0000  |
#   3 H              0.0000    0.0000   -0.5000  |  0.1414    0.4673   -0.0000  |  0.1827    0.4582   -0.0000  |
#   4 H              0.0000   -0.0000    0.5000  |  0.1414   -0.4673   -0.0000  | -0.1827    0.4582   -0.0000  |
#   5 H              0.0000   -0.0000    0.5000  | -0.1414    0.4673    0.0000  |  0.1827   -0.4582    0.0000  |
#   6 H              0.0000    0.0000   -0.5000  | -0.1414   -0.4673    0.0000  | -0.1827   -0.4582    0.0000  |
#
#   Index:                        7                              8                              9
#   Frequency:                 1625.83                        1826.39                        3287.03
#   Force constant:            1.7323                         5.3156                         6.6693
#   Reduced mass:              1.1123                         2.7047                         1.0477
#   IR intensity:              8.5595                         0.0000                         20.4114
#   Raman activ.:              0.0000                         15.7968                        0.0000
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.0000   -0.0688   -0.0000  | -0.0000   -0.2777    0.0000  |  0.0000   -0.0425   -0.0000  |
#   2 C              0.0000   -0.0689   -0.0000  |  0.0000    0.2777    0.0000  | -0.0000   -0.0425   -0.0000  |
#   3 H              0.2817    0.4102   -0.0000  |  0.3753    0.2657   -0.0000  | -0.4302    0.2530    0.0000  |
#   4 H             -0.2817    0.4102    0.0000  | -0.3753    0.2657   -0.0000  |  0.4302    0.2530   -0.0000  |
#   5 H             -0.2817    0.4102    0.0000  |  0.3753   -0.2657   -0.0000  |  0.4302    0.2530   -0.0000  |
#   6 H              0.2817    0.4102   -0.0000  | -0.3753   -0.2657   -0.0000  | -0.4302    0.2530    0.0000  |
#
#   Index:                       10                             11                             12
#   Frequency:                 3310.86                        3370.94                        3400.74
#   Force constant:            6.9594                         7.4785                         7.6183
#   Reduced mass:              1.0776                         1.1170                         1.1181
#   IR intensity:              0.0000                         0.0000                         41.1205
#   Raman activ.:             190.4500                       127.7554                        0.0000
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C              0.0000    0.0562    0.0000  | -0.0704   -0.0000    0.0000  |  0.0707   -0.0000    0.0000  |
#   2 C              0.0000   -0.0562    0.0000  |  0.0704    0.0000   -0.0000  |  0.0707    0.0000    0.0000  |
#   3 H              0.4283   -0.2549   -0.0000  |  0.4215   -0.2643   -0.0000  | -0.4214    0.2645   -0.0000  |
#   4 H             -0.4283   -0.2549   -0.0000  |  0.4215    0.2643    0.0000  | -0.4214   -0.2645   -0.0000  |
#   5 H              0.4283    0.2549   -0.0000  | -0.4215   -0.2643    0.0000  | -0.4214   -0.2645   -0.0000  |
#   6 H             -0.4283    0.2549   -0.0000  | -0.4215    0.2643    0.0000  | -0.4214    0.2645   -0.0000  |
#
#
#                                                    Vibrational Analysis
#                                                   ======================
#
#                  Harmonic frequencies (in cm**-1), force constants (in mdyne/A), reduced masses (in amu),
#                           IR intensities (in km/mol), Raman scattering activities (in A**4/amu),
#                                          and Cartesian normal mode displacements.
#
#
#   Index:                        1                              2                              3
#   Frequency:                 464.91                         507.65                         756.18
#   Force constant:            0.5167                         0.7198                         0.5313
#   Reduced mass:              4.0571                         4.7407                         1.5770
#   IR intensity:              74.0780                        30.8760                        6.7743
#   Raman activ.:              10.2368                        9.3870                         12.1342
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.4276    0.0047    0.0000  | -0.0115   -0.2002   -0.0000  | -0.0000   -0.0000   -0.2078  |
#   2 C              0.0407   -0.0134   -0.0000  |  0.2166   -0.2270   -0.0000  |  0.0000   -0.0000    0.0372  |
#   3 F              0.2377    0.0052   -0.0000  | -0.1735    0.3043   -0.0000  |  0.0000    0.0000    0.0661  |
#   4 H             -0.4637    0.0488    0.0000  | -0.0302   -0.1722    0.0000  | -0.0000    0.0000    0.4563  |
#   5 H              0.3021   -0.4484    0.0000  |  0.4294   -0.5752    0.0000  | -0.0000    0.0000   -0.4205  |
#   6 H              0.2911    0.4054   -0.0000  |  0.4269    0.1027   -0.0000  | -0.0000   -0.0000    0.7524  |
#
#   Index:                        4                              5                              6
#   Frequency:                 986.31                         1075.63                        1151.12
#   Force constant:            0.6164                         0.8235                         1.0406
#   Reduced mass:              1.0754                         1.2081                         1.3329
#   IR intensity:              51.0482                        2.9638                         82.6877
#   Raman activ.:              5.2204                         6.0841                         3.2479
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.0000   -0.0000    0.0741  |  0.0514    0.0165    0.0000  |  0.0000   -0.0000    0.0477  |
#   2 C              0.0000   -0.0000   -0.0228  | -0.1104    0.0475   -0.0000  | -0.0000   -0.0000   -0.1651  |
#   3 F              0.0000    0.0000    0.0085  | -0.0059   -0.0219    0.0000  |  0.0000   -0.0000   -0.0019  |
#   4 H             -0.0000    0.0000   -0.7627  |  0.3956   -0.4614   -0.0000  | -0.0000    0.0000    0.0471  |
#   5 H             -0.0000    0.0000   -0.4580  |  0.2073   -0.4537   -0.0000  | -0.0000    0.0000    0.7436  |
#   6 H             -0.0000   -0.0000    0.4499  |  0.2112    0.5651    0.0000  |  0.0000    0.0000    0.6444  |
#
#   Index:                        7                              8                              9
#   Frequency:                 1363.17                        1528.23                        1779.40
#   Force constant:            1.4074                         1.7963                         5.9697
#   Reduced mass:              1.2855                         1.3054                         3.2000
#   IR intensity:              24.4752                        2.6123                         30.7176
#   Raman activ.:              3.8078                         30.7648                        23.0810
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.1099    0.0126    0.0000  | -0.0040    0.1583   -0.0000  |  0.0158   -0.2930    0.0000  |
#   2 C              0.1049    0.0424   -0.0000  | -0.0009   -0.0426   -0.0000  | -0.0055    0.3357   -0.0000  |
#   3 F             -0.0109    0.0013   -0.0000  | -0.0045   -0.0086   -0.0000  |  0.0078    0.0140   -0.0000  |
#   4 H              0.4379   -0.7587    0.0000  |  0.1268    0.0096    0.0000  | -0.2499   -0.0386    0.0000  |
#   5 H             -0.0846    0.3473    0.0000  |  0.3273   -0.6239    0.0000  |  0.4736   -0.3527    0.0000  |
#   6 H             -0.0885   -0.2680    0.0000  | -0.3116   -0.6029    0.0000  | -0.4930   -0.3812   -0.0000  |
#
#   Index:                       10                             11                             12
#   Frequency:                 3310.74                        3389.61                        3407.94
#   Force constant:            6.8662                         7.4947                         7.5940
#   Reduced mass:              1.0632                         1.1071                         1.1098
#   IR intensity:              1.8380                         1.5878                         0.3347
#   Raman activ.:              73.5412                       105.4538                        38.0545
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.0099    0.0006    0.0000  |  0.0595    0.0509   -0.0000  |  0.0345    0.0269   -0.0000  |
#   2 C              0.0041   -0.0700    0.0000  | -0.0497   -0.0200   -0.0000  |  0.0855   -0.0053   -0.0000  |
#   3 F              0.0013    0.0018   -0.0000  |  0.0015    0.0013    0.0000  |  0.0003    0.0010    0.0000  |
#   4 H              0.1252    0.0827   -0.0000  | -0.7020   -0.5079    0.0000  | -0.3845   -0.2821    0.0000  |
#   5 H              0.5582    0.3353   -0.0000  |  0.3711    0.2325    0.0000  | -0.5172   -0.3224    0.0000  |
#   6 H             -0.6388    0.3748   -0.0000  |  0.1854   -0.1188    0.0000  | -0.5336    0.3274    0.0000  |
#
#
#                                                    Vibrational Analysis
#                                                   ======================
#
#                  Harmonic frequencies (in cm**-1), force constants (in mdyne/A), reduced masses (in amu),
#                           IR intensities (in km/mol), Raman scattering activities (in A**4/amu),
#                                          and Cartesian normal mode displacements.
#
#
#   Index:                        1                              2                              3
#   Frequency:                 561.11                         744.01                         1039.92
#   Force constant:            0.5897                         0.4459                         1.7329
#   Reduced mass:              3.1791                         1.3672                         2.7197
#   IR intensity:              0.3651                         19.0415                        21.2388
#   Raman activ.:              4.2523                         11.9860                        5.5326
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C              0.1626    0.1814   -0.0000  |  0.0000    0.0000    0.1703  |  0.2535   -0.0368    0.0000  |
#   2 C             -0.2221    0.1711    0.0000  | -0.0000    0.0000   -0.0365  |  0.1187   -0.1236   -0.0000  |
#   3 Cl             0.0409   -0.1315    0.0000  |  0.0000   -0.0000   -0.0271  | -0.1220    0.0669   -0.0000  |
#   4 H              0.1970    0.1222    0.0000  | -0.0000    0.0000   -0.3253  |  0.2978   -0.0626    0.0000  |
#   5 H             -0.4473    0.5465   -0.0000  | -0.0000    0.0000    0.4801  | -0.1866    0.3683    0.0000  |
#   6 H             -0.4810   -0.2434    0.0000  | -0.0000    0.0000   -0.7953  | -0.2543   -0.7469   -0.0000  |
#
#   Index:                        4                              5                              6
#   Frequency:                 1091.80                        1160.32                        1210.61
#   Force constant:            0.7620                         1.1096                         1.1061
#   Reduced mass:              1.0850                         1.3988                         1.2810
#   IR intensity:              79.9510                        35.3623                        12.0373
#   Raman activ.:              1.2982                         6.4864                         8.4247
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C              0.0000   -0.0000    0.0811  |  0.0000   -0.0000   -0.0804  | -0.1151   -0.0020    0.0000  |
#   2 C             -0.0000   -0.0000    0.0207  | -0.0000   -0.0000    0.1705  |  0.0859   -0.0223    0.0000  |
#   3 Cl            -0.0000    0.0000    0.0001  | -0.0000    0.0000    0.0007  |  0.0338   -0.0055    0.0000  |
#   4 H              0.0000   -0.0000   -0.7871  |  0.0000   -0.0000    0.2396  | -0.5087    0.5826   -0.0000  |
#   5 H              0.0000   -0.0000   -0.5894  | -0.0000    0.0000   -0.5860  | -0.1489    0.3497   -0.0001  |
#   6 H              0.0000    0.0000    0.1616  |  0.0000    0.0000   -0.7508  | -0.1832   -0.4489   -0.0000  |
#
#   Index:                        7                              8                              9
#   Frequency:                 1452.51                        1603.48                        1816.14
#   Force constant:            1.8741                         1.9821                         6.3335
#   Reduced mass:              1.5077                         1.3084                         3.2591
#   IR intensity:              7.9744                         11.1027                        31.8871
#   Raman activ.:              19.2264                        23.5724                        24.3314
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C              0.1409    0.0527   -0.0000  | -0.0718    0.1451   -0.0000  |  0.0885   -0.3050   -0.0000  |
#   2 C             -0.1043   -0.1064   -0.0000  |  0.0196   -0.0069    0.0000  | -0.0268    0.3195    0.0000  |
#   3 Cl            -0.0105    0.0085    0.0000  |  0.0123   -0.0075   -0.0000  | -0.0136    0.0107   -0.0000  |
#   4 H             -0.2814    0.7362    0.0000  |  0.1666   -0.2101    0.0000  | -0.2676    0.1637   -0.0000  |
#   5 H              0.1475   -0.5364    0.0000  |  0.3377   -0.5758   -0.0000  |  0.4743   -0.4016   -0.0000  |
#   6 H              0.0672    0.1406   -0.0000  | -0.3158   -0.5965   -0.0000  | -0.4634   -0.3110   -0.0000  |
#
#   Index:                       10                             11                             12
#   Frequency:                 3301.18                        3359.62                        3395.25
#   Force constant:            6.8289                         7.3173                         7.5740
#   Reduced mass:              1.0636                         1.1003                         1.1152
#   IR intensity:              2.4849                         1.4337                         13.0062
#   Raman activ.:              70.8980                       118.6148                        54.7711
#   Normal mode:       X         Y         Z     |    X         Y         Z     |    X         Y         Z     |
#   1 C             -0.0129    0.0017   -0.0000  |  0.0694    0.0494    0.0000  |  0.0215    0.0129    0.0000  |
#   2 C              0.0016   -0.0698    0.0000  | -0.0280   -0.0188    0.0000  |  0.0954   -0.0034    0.0000  |
#   3 Cl             0.0007    0.0005   -0.0000  | -0.0004    0.0013    0.0000  | -0.0005    0.0006   -0.0000  |
#   4 H              0.1359    0.0832    0.0000  | -0.7923   -0.5219   -0.0000  | -0.2209   -0.1479   -0.0000  |
#   5 H              0.5854    0.3454    0.0000  |  0.2510    0.1509   -0.0000  | -0.5647   -0.3506   -0.0000  |
#   6 H             -0.6120    0.3648   -0.0000  |  0.0633   -0.0401    0.0000  | -0.5876    0.3640   -0.0000  |

# %%
# Plot the IR spectra
plt.figure(figsize=(7,4))

eth_x, eth_ir = ethene_hessian_drv.frequencies, ethene_hessian_drv.ir_intensities
flo_x, flo_ir = fluoroethene_hessian_drv.frequencies, fluoroethene_hessian_drv.ir_intensities
chl_x, chl_ir = chloroethene_hessian_drv.frequencies, chloroethene_hessian_drv.ir_intensities

eth_xl, eth_irl = add_broadening(eth_x, eth_ir, line_profile='Gaussian', line_param=20, step=2)
flo_xl, flo_irl = add_broadening(flo_x, flo_ir, line_profile='Gaussian', line_param=20, step=2)
chl_xl, chl_irl = add_broadening(chl_x, chl_ir, line_profile='Gaussian', line_param=20, step=2)

plt.plot(eth_xl, eth_irl, label='Ethene')
plt.plot(eth_x, eth_ir, 'x', label='Ethene')

plt.plot(flo_xl, flo_irl, label='Fluoroethene')
plt.plot(flo_x, flo_ir, '*', label='Fluoroethene')

plt.plot(chl_xl, chl_irl, label='Chloroethene')
plt.plot(chl_x, chl_ir, 'o' , label='Chloroethene')

plt.xlabel('Wavenumber (cm**-1)')
plt.axis(xmin=3200, xmax=3500)
#plt.axis(ymin=-0.2, ymax=1.5)
plt.axis(ymin=-0.2, ymax=50)
plt.ylabel('IR intensity (km/mol)')
plt.title("Calculated IR sepctra of substituted ethenes")
plt.legend()
plt.tight_layout(); plt.show()

# %%
# Plot the IR spectra
plt.figure(figsize=(7,4))

eth_x, eth_ir = ethene_hessian_drv.frequencies, ethene_hessian_drv.raman_intensities
flo_x, flo_ir = fluoroethene_hessian_drv.frequencies, fluoroethene_hessian_drv.raman_intensities
chl_x, chl_ir = chloroethene_hessian_drv.frequencies, chloroethene_hessian_drv.raman_intensities

eth_xl, eth_irl = add_broadening(eth_x, eth_ir, line_profile='Gaussian', line_param=20, step=2)
flo_xl, flo_irl = add_broadening(flo_x, flo_ir, line_profile='Gaussian', line_param=20, step=2)
chl_xl, chl_irl = add_broadening(chl_x, chl_ir, line_profile='Gaussian', line_param=20, step=2)

plt.plot(eth_xl, eth_irl, label='Ethene')
plt.plot(eth_x, eth_ir, 'x', label='Ethene')

plt.plot(flo_xl, flo_irl, label='Fluoroethene')
plt.plot(flo_x, flo_ir, '*', label='Fluoroethene')

plt.plot(chl_xl, chl_irl, label='Chloroethene')
plt.plot(chl_x, chl_ir, 'o' , label='Chloroethene')

plt.xlabel('Wavenumber (cm**-1)')
plt.axis(xmin=3200, xmax=3500)
#plt.axis(ymin=-0.2, ymax=1.5)
#plt.axis(ymin=-0.2, ymax=50)
plt.ylabel('Raman activities')
plt.title("Calculated Raman sepctra of substituted ethenes")
plt.legend()
plt.tight_layout(); plt.show()

# %%
# Get the displacements of the normal mode
ethene_h1 = get_normal_mode(ethene, ethene_hessian_drv.normal_modes[-1])
fluoroethene_h1 = get_normal_mode(fluoroethene, fluoroethene_hessian_drv.normal_modes[-3])
chloroethene_h1 = get_normal_mode(chloroethene, chloroethene_hessian_drv.normal_modes[-3])

# %%
# # Animate the vibration
# view = p3d.view(viewergrid=(1,1), width=300, height=200, linked=True)
# view.addModel(fluoroethene_h1, "xyz", {'vibrate': {'frames':10,'amplitude':0.75}}, viewer=(0,0))
# view.setStyle({'stick':{}})
# view.animate({'loop': 'backAndForth'})
# view.zoomTo()
# view.show()

# %% [markdown]
# ## IR intensities and Raman activities
#
# To rationalize why the IR and Raman spectra look as they do, calculate how the dipole moment and polarizability change during particular vibrational motions. Look at the Hydrogen stretching modes and select a mode which is IR-active in ethene, but is "suppressed" in fluoroethene or chloroethene. What is the dipole moment in the optimized molecule? How does the dipole moment change during the vibration?

# %%
ethene_prop = vlx.firstorderprop.FirstOrderProperties()
ethene_prop.compute_scf_prop(opt_ethene, ethene_basis, ethene_scfdrv.scf_tensors)
ethene_dipole_moment = ethene_prop.get_property('dipole moment')

ethene_moments = []

# %%
natm = opt_ethene.number_of_atoms()    
new_ethene_scfdrv = vlx.scfrestdriver.ScfRestrictedDriver()
displacements = ethene_hessian_drv.normal_modes[-1].reshape(natm, 3)
labels = opt_ethene.get_labels()

print(displacements.shape)
# Out:
# (6, 3)

# %%
for x in [-0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75]:
    coords = opt_ethene.get_coordinates() * bohr_in_angstroms()
    coords += x * displacements
    new_ethene = vlx.molecule.Molecule(labels, coords, units='angstrom')
    new_ethene_scfdrv.compute(new_ethene, ethene_basis)
    ethene_prop.compute_scf_prop(new_ethene, ethene_basis, new_ethene_scfdrv.scf_tensors)
    ethene_dipole_moment = ethene_prop.get_property('dipole moment')
    ethene_moments.append(ethene_dipole_moment)
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Scheme            : Cauchy Schwarz + Density
#                    ERI Screening Mode              : Dynamic
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Nuclear repulsion energy: 35.8615538931 a.u.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
# * Info * SAD initial guess computed in 0.00 sec.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -77.240641511066 a.u. Time: 0.19 sec.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1       -77.240641609634    0.0000000000      0.00020416      0.00003698      0.00000000
#                   2       -77.240641627454   -0.0000000178      0.00003419      0.00000485      0.00025092
#                   3       -77.240641627676   -0.0000000002      0.00000863      0.00000147      0.00001899
#                   4       -77.240641627693   -0.0000000000      0.00000092      0.00000014      0.00000686
#
#                *** SCF converged in 4 iterations. Time: 0.18 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :      -77.2406416277 a.u.
#                Electronic Energy                  :     -113.1021955208 a.u.
#                Nuclear Repulsion Energy           :       35.8615538931 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000009177 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1.0
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                  Spin Restricted Orbitals
#                                                  ------------------------
#
#                Molecular Orbital No.   4:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.92630 a.u.
#                (   1 C   2s  :    -0.23) (   1 C   1p+1:     0.17) (   1 C   1p-1:     0.18)
#                (   2 C   2s  :     0.23) (   2 C   1p+1:    -0.17) (   2 C   1p-1:     0.18)
#                (   4 H   1s  :    -0.28) (   4 H   2s  :    -0.25) (   6 H   1s  :     0.28)
#                (   6 H   2s  :     0.25)
#
#                Molecular Orbital No.   5:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.73471 a.u.
#                (   1 C   3s  :     0.18) (   1 C   1p+1:     0.25) (   1 C   1p-1:     0.35)
#                (   2 C   3s  :     0.18) (   2 C   1p+1:     0.25) (   2 C   1p-1:    -0.35)
#                (   4 H   1s  :    -0.21) (   6 H   1s  :    -0.21)
#
#                Molecular Orbital No.   6:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.52549 a.u.
#                (   1 C   1p+1:    -0.20) (   1 C   1p-1:     0.27) (   2 C   1p+1:    -0.20)
#                (   2 C   1p-1:    -0.27) (   3 H   1s  :    -0.17) (   3 H   2s  :    -0.20)
#                (   5 H   1s  :    -0.17) (   5 H   2s  :    -0.20)
#
#                Molecular Orbital No.   7:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.44633 a.u.
#                (   1 C   1p+1:    -0.26) (   1 C   2p+1:    -0.17) (   2 C   1p+1:     0.26)
#                (   2 C   2p+1:     0.17) (   3 H   1s  :    -0.21) (   3 H   2s  :    -0.27)
#                (   5 H   1s  :     0.21) (   5 H   2s  :     0.27)
#
#                Molecular Orbital No.   8:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.39263 a.u.
#                (   1 C   1p0 :     0.39) (   1 C   2p0 :     0.29) (   2 C   1p0 :     0.39)
#                (   2 C   2p0 :     0.29)
#
#                Molecular Orbital No.   9:
#                --------------------------
#                Occupation: 0.000 Energy:    0.15140 a.u.
#                (   1 C   3s  :    -0.57) (   1 C   1p+1:    -0.21) (   1 C   2p+1:    -0.33)
#                (   1 C   2p-1:     0.28) (   2 C   3s  :    -0.57) (   2 C   1p+1:    -0.21)
#                (   2 C   2p+1:    -0.33) (   2 C   2p-1:    -0.28) (   3 H   2s  :     0.84)
#                (   5 H   2s  :     0.84)
#
#                Molecular Orbital No.  10:
#                --------------------------
#                Occupation: 0.000 Energy:    0

#
#                Molecular Orbital No.   9:
#                --------------------------
#                Occupation: 0.000 Energy:    0.15139 a.u.
#                (   1 C   3s  :    -0.57) (   1 C   1p+1:     0.21) (   1 C   2p+1:     0.33)
#                (   1 C   2p-1:     0.28) (   2 C   3s  :    -0.57) (   2 C   1p+1:     0.21)
#                (   2 C   2p+1:     0.33) (   2 C   2p-1:    -0.28) (   4 H   2s  :     0.84)
#                (   6 H   2s  :     0.84)
#
#                Molecular Orbital No.  10:
#                --------------------------
#                Occupation: 0.000 Energy:    0.16694 a.u.
#                (   1 C   1p0 :     0.37) (   1 C   2p0 :     0.71) (   2 C   1p0 :    -0.37)
#                (   2 C   2p0 :    -0.71)
#
#                Molecular Orbital No.  11:
#                --------------------------
#                Occupation: 0.000 Energy:    0.25653 a.u.
#                (   1 C   3s  :    -0.85) (   1 C   1p+1:     0.26) (   1 C   2p+1:     0.58)
#                (   1 C   2p-1:     0.31) (   2 C   3s  :     0.85) (   2 C   1p+1:    -0.26)
#                (   2 C   2p+1:    -0.58) (   2 C   2p-1:     0.31) (   3 H   2s  :     0.31)
#                (   4 H   2s  :     0.96) (   5 H   2s  :    -0.31) (   6 H   2s  :    -0.96)
#
#                Molecular Orbital No.  12:
#                --------------------------
#                Occupation: 0.000 Energy:    0.33522 a.u.
#                (   1 C   3s  :     2.64) (   1 C   1p+1:     0.16) (   1 C   2p+1:     0.85)
#                (   1 C   2p-1:    -0.70) (   2 C   3s  :     2.64) (   2 C   1p+1:     0.16)
#                (   2 C   2p+1:     0.85) (   2 C   2p-1:     0.70) (   3 H   2s  :    -3.20)
#                (   5 H   2s  :    -3.20)
#
#                Molecular Orbital No.  13:
#                --------------------------
#                Occupation: 0.000 Energy:    0.37273 a.u.
#                (   1 C   3s  :     3.73) (   1 C   2p+1:     1.65) (   2 C   3s  :    -3.73)
#                (   2 C   2p+1:    -1.65) (   3 H   2s  :    -3.86) (   4 H   2s  :     0.37)
#                (   5 H   2s  :     3.86) (   6 H   2s  :    -0.37)

# %%
ethene_moments_norms = []

for m in ethene_moments:
    norm = np.linalg.norm(m)
    ethene_moments_norms.append(norm)

# %%
disp = [-0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75]


plt.plot(disp, ethene_moments_norms, label='Ethene')

plt.xlabel('Displacement (%)')
plt.ylabel('Norm of dipole moment (a.u.)')
plt.title("Dipole Moment along the 3407.94 cm-1 mode")
plt.legend()
plt.tight_layout(); plt.show()

# %%
ethene_lrdrv = vlx.lrsolver.LinearResponseSolver()
ethene_pol_dict = ethene_lrdrv.compute(opt_ethene, ethene_basis, ethene_scfdrv.scf_tensors)
# Out:
#
#                                                Linear Response Solver Setup
#                                               ==============================
#
#                                Number of Frequencies           : 1
#                                Max. Number of Iterations       : 150
#                                Convergence Threshold           : 1.0e-04
#                                ERI Screening Scheme            : Cauchy Schwarz + Density
#                                ERI Screening Threshold         : 1.0e-15
#
# * Info * Processing Fock builds... (batch size: 3)
# * Info *   batch 1/1
#
# * Info * 0 gerade trial vectors in reduced space
# * Info * 3 ungerade trial vectors in reduced space
#
# * Info * 17.43 kB of memory used for subspace procedure on the master node
# * Info * 824.33 MB of memory available for the solver on the master node
#
#                *** Iteration:   1 * Residuals (Max,Min): 7.16e-01 and 1.66e-01
#
#                <<x;x>>_0.0000 :    -18.24498490 Residual Norm: 0.30956315
#                <<y;y>>_0.0000 :    -28.28886891 Residual Norm: 0.71568235
#                <<z;z>>_0.0000 :     -7.14739686 Residual Norm: 0.16588582
#
# * Info * Processing Fock builds... (batch size: 3)
# * Info *   batch 1/1
#
# * Info * 0 gerade trial vectors in reduced space
# * Info * 6 ungerade trial vectors in reduced space
#
# * Info * 24.34 kB of memory used for subspace procedure on the master node
# * Info * 824.24 MB of memory available for the solver on the master node
#
#                *** Iteration:   2 * Residuals (Max,Min): 1.67e-01 and 3.48e-02
#
#                <<x;x>>_0.0000 :    -18.80258270 Residual Norm: 0.03713291
#                <<y;y>>_0.0000 :    -32.06995211 Residual Norm: 0.16749198
#                <<z;z>>_0.0000 :     -7.17546132 Residual Norm: 0.03478168
#
# * Info * Processing Fock builds... (batch size: 3)
# * Info *   batch 1/1
#
# * Info * 0 gerade trial vectors in reduced space
# * Info * 9 ungerade trial vectors in reduced space
#
# * Info * 31.25 kB of memory used for subspace procedure on the master node
# * Info * 819.75 MB of memory available for the solver on the master node
#
#                *** Iteration:   3 * Residuals (Max,Min): 4.14e-02 and 5.06e-03
#
#                <<x;x>>_0.0000 :    -18.80806679 Residual Norm: 0.00605212
#                <<y;y>>_0.0000 :    -32.55380112 Residual Norm: 0.04135830
#                <<z;z>>_0.0000 :     -7.17600665 Residual Norm: 0.00506130
#
# * Info * Processing Fock builds... (batch size: 3)
# * Info *   batch 1/1
#
# * Info * 0 gerade trial vectors in reduced space
# * Info * 12 ungerade trial vectors in reduced space
#
# * Info * 38.17 kB of memory used for subspace procedure on the master node
# * Info * 815.86 MB of memory available for the solver on the master node
#
#                *** Iteration:   4 * Residuals (Max,Min): 7.56e-03 and 3.65e-04
#
#                <<x;x>>_0.0000 :    -18.80812170 Residual Norm: 0.00076679
#                <<y;y>>_0.0000 :    -32.57830335 Residual Norm: 0.00756479
#                <<z;z>>_0.0000 :     -7.17601766 Residual Norm: 0.00036527
#
# * Info * Processing Fock builds... (batch size: 3)
# * Info *   batch 1/1
#
# * Info * 0 gerade trial vectors in reduced space
# * Info * 15 ungerade trial vectors in reduced space
#
# * Info * 45.10 kB of memory used for subspace procedure on the master node
# * Info * 812.41 MB of memory available for the solver on the master node
#
#                *** Iteration:   5 * Residuals (Max,Min): 1.20e-03 and 4.70e-05
#
#                <<x;x>>_0.0000 :    -18.80812277 Residual Norm: 0.00005100
#                <<y;y>>_0.0000 :    -32.57875162 Residual Norm: 0.00120353
#                <<z;z>>_0.0000 :     -7.17601780 Residual Norm: 0.00004696
#
# * Info * Processing Fock builds... (batch size: 1)
# * Info *   batch 1/1
#
# * Info * 0 gerade trial vectors in reduced space
# * Info * 16 ungerade trial vectors in reduced space
#
# * Info * 47.21 kB of memory used for subspace procedure on the master node
# * Info * 808.49 MB of memory available for the solver on the master node
#
#                *** Iteration:   6 * Residuals (Max,Min): 9.35e-05 and 4.70e-05
#
#                <<y;y>>_0.0000 :    -32.57875523 Residual Norm: 0.00009352
#
#                *** Linear response converged in 6 iterations. Time: 0.18 sec

# %%
ethene_pol_dict['response_functions']
# Out:
# {('x', 'x', 0): -18.808122772237375,
#  ('y', 'x', 0): 5.281111226270171e-08,
#  ('z', 'x', 0): 2.4011549001463333e-09,
#  ('x', 'z', 0): 2.401154915312512e-09,
#  ('y', 'z', 0): 2.0485425712951626e-08,
#  ('z', 'z', 0): -7.176017800682624,
#  ('x', 'y', 0): 5.281115557089388e-08,
#  ('y', 'y', 0): -32.578755225478496,
#  ('z', 'y', 0): 2.0485429949122227e-08}
