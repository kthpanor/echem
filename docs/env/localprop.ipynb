# %% [markdown]
# # Localized properties
#
# In this section, we will describe different ways to define and calculate local atomic properties that are used in classical representations of molecules.
#
# We will consider:
#
# - [ESP atomic charges](sec:esp_charges)
# - [CHELPG atomic charges](sec:chelpg_charges)
# - [RESP atomic charges](sec:resp_charges)
# - [LoProp charges and polarizabilities](sec:loprop)
