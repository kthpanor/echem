# %% [markdown]
# # Molecular structure

# %%
import py3Dmol
import veloxchem as vlx

# %% [markdown]
# The structure of a molecular system can be visualized with `py3Dmol`, using an xyz-file:

# %%
thymine_xyz = """15
*
 C     0.095722    -0.037785    -1.093615
 C    -0.011848     1.408694    -1.113404
 C    -0.204706     2.048475     0.052807
 N    -0.302595     1.390520     1.249226
 C    -0.214596     0.023933     1.378238
 N    -0.017387    -0.607231     0.171757
 O     0.270287    -0.735594    -2.076393
 C     0.098029     2.096194    -2.424990
 H     1.052976     1.874860    -2.891573
 H     0.002157     3.170639    -2.310554
 H    -0.671531     1.743694    -3.104794
 O    -0.301905    -0.554734     2.440234
 H    -0.292790     3.119685     0.106201
 H     0.053626    -1.612452     0.215637
 H    -0.446827     1.892203     2.107092
"""

viewer = py3Dmol.view(width=400, height=300)
# black outline for nicer-looking figures
viewer.setViewStyle({"style": "outline", "width": 0.05})
viewer.addModel(thymine_xyz)
# visualize with the sticks and spheres
viewer.setStyle({"stick":{},"sphere": {"scale":0.25}})
# rotate for a better initial view
viewer.rotate(-90, "y")
viewer.show()
# Out:
# <div id="3dmolviewer_17755531290574572"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17755531290574572" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17755531290574572 = null;
# var warn = document.getElementById("3dmolwarning_17755531290574572");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17755531290574572 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17755531290574572"),{backgroundColor:"white"});
# viewer_17755531290574572.zoomTo();
# 	viewer_17755531290574572.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17755531290574572.addModel("15\n*\n C     0.095722    -0.037785    -1.093615\n C    -0.011848     1.408694    -1.113404\n C    -0.204706     2.048475     0.052807\n N    -0.302595     1.390520     1.249226\n C    -0.214596     0.023933     1.378238\n N    -0.017387    -0.607231     0.171757\n O     0.270287    -0.735594    -2.076393\n C     0.098029     2.096194    -2.424990\n H     1.052976     1.874860    -2.891573\n H     0.002157     3.170639    -2.310554\n H    -0.671531     1.743694    -3.104794\n O    -0.301905    -0.554734     2.440234\n H    -0.292790     3.119685     0.106201\n H     0.053626    -1.612452     0.215637\n H    -0.446827     1.892203     2.107092\n");
# 	viewer_17755531290574572.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17755531290574572.rotate(-90,"y");
# viewer_17755531290574572.render();
# });
# </script>

# %% [markdown]
# This creates a dynamic view which can be rotated and zoomed in and out.
#
# This functionality is available through `VeloxChem` using `molecule.show()`:

# %%
molecule = vlx.Molecule.read_xyz_string(thymine_xyz)
molecule.show()
# Out:
# <div id="3dmolviewer_1775553129070155"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1775553129070155" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1775553129070155 = null;
# var warn = document.getElementById("3dmolwarning_1775553129070155");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1775553129070155 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1775553129070155"),{backgroundColor:"white"});
# viewer_1775553129070155.zoomTo();
# 	viewer_1775553129070155.addModel("15\n\nC              0.095722000000        -0.037785000000        -1.093615000000\nC             -0.011848000000         1.408694000000        -1.113404000000\nC             -0.204706000000         2.048475000000         0.052807000000\nN             -0.302595000000         1.390520000000         1.249226000000\nC             -0.214596000000         0.023933000000         1.378238000000\nN             -0.017387000000        -0.607231000000         0.171757000000\nO              0.270287000000        -0.735594000000        -2.076393000000\nC              0.098029000000         2.096194000000        -2.424990000000\nH              1.052976000000         1.874860000000        -2.891573000000\nH              0.002157000000         3.170639000000        -2.310554000000\nH             -0.671531000000         1.743694000000        -3.104794000000\nO             -0.301905000000        -0.554734000000         2.440234000000\nH             -0.292790000000         3.119685000000         0.106201000000\nH              0.053626000000        -1.612452000000         0.215637000000\nH             -0.446827000000         1.892203000000         2.107092000000\n");
# 	viewer_1775553129070155.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1775553129070155.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1775553129070155.zoomTo();
# viewer_1775553129070155.render();
# });
# </script>

# %% [markdown]
# Alternatively, PDF-files can be loaded directly from the PDB-library, and illustrated with different models (here looking at an [XRD structure](https://www.rcsb.org/structure/6w1o) of [photosystem II](https://www.pnas.org/doi/full/10.1073/pnas.2000529117)):

# %%
viewer = py3Dmol.view(
    query="pdb:6W1O", viewergrid=(1, 3), width=800, height=300, linked=False
)
viewer.setStyle({"cartoon": {"color": "spectrum"}}, viewer=(0, 1))
viewer.setStyle({"cartoon": {}}, viewer=(0, 2))
viewer.addStyle({"elem": "Mn"}, {"sphere": {"color": "red"}}, viewer=(0, 2))
viewer.addStyle({"elem": "Ca"}, {"sphere": {"color": "yellow"}}, viewer=(0, 2))
viewer.show()
# Out:
# <div id="3dmolviewer_17755535535581706"  style="position: relative; width: 800px; height: 300px;">
#         <p id="3dmolwarning_17755535535581706" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17755535535581706 = null;
# var warn = document.getElementById("3dmolwarning_17755535535581706");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_17755535535581706 = null;
# viewergrid_17755535535581706 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_17755535535581706"),{rows: 1, cols: 3, control_all: false},{backgroundColor:"white"});
# viewer_17755535535581706 = viewergrid_17755535535581706[0][0];
# $3Dmol.download("pdb:6W1O", viewergrid_17755535535581706[0][0], {}, function() {
# $3Dmol.download("pdb:6W1O", viewergrid_17755535535581706[0][1], {}, function() {
# $3Dmol.download("pdb:6W1O", viewergrid_17755535535581706[0][2], {}, function() {
# viewergrid_17755535535581706[0][0].zoomTo();viewergrid_17755535535581706[0][1].zoomTo();viewergrid_17755535535581706[0][2].zoomTo();	viewergrid_17755535535581706[0][1].setStyle({"cartoon": {"color": "spectrum"}});
# 	viewergrid_17755535535581706[0][2].setStyle({"cartoon": {}});
# 	viewergrid_17755535535581706[0][2].addStyle({"elem": "Mn"},{"sphere": {"color": "red"}});
# 	viewergrid_17755535535581706[0][2].addStyle({"elem": "Ca"},{"sphere": {"color": "yellow"}});
# viewergrid_17755535535581706[0][2].render();
# viewergrid_17755535535581706[0][1].render();
# viewergrid_17755535535581706[0][0].render();
# })
# })
# })
# });
# </script>

# %% [markdown]
# Here we illustrate this by line structure, and more cartoonish image with and without coloring different strands differently. To the right we see white ribbons with manganese and calcium atoms colored in red and yellow, respectively. These shows the position of the oxygen-evolving complex of photosystem II, which is the site of water-splitting and oxygen generation.
