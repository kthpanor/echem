# %% [markdown]
# # Molecular structure

# %%
import py3Dmol
import veloxchem as vlx
# Out:
# [thomas-Latitude-5580:86188] mca_base_component_repository_open: unable to open mca_btl_openib: librdmacm.so.1: cannot open shared object file: No such file or directory (ignored)
# * Warning * Environment variable OMP_NUM_THREADS not set.
# * Warning * Setting OMP_NUM_THREADS to 4.

# %% [markdown]
# The structure of a molecular system can be visualized with `py3Dmol`, using an xyz-file:

# %%
thymine_xyz = """15
*
 C     0.095722    -0.037785    -1.093615
 C    -0.011848     1.408694    -1.113404
 C    -0.204706     2.048475     0.052807
 N    -0.302595     1.390520     1.249226
 C    -0.214596     0.023933     1.378238
 N    -0.017387    -0.607231     0.171757
 O     0.270287    -0.735594    -2.076393
 C     0.098029     2.096194    -2.424990
 H     1.052976     1.874860    -2.891573
 H     0.002157     3.170639    -2.310554
 H    -0.671531     1.743694    -3.104794
 O    -0.301905    -0.554734     2.440234
 H    -0.292790     3.119685     0.106201
 H     0.053626    -1.612452     0.215637
 H    -0.446827     1.892203     2.107092
"""

viewer = py3Dmol.view(width=400, height=300)
# black outline for nicer-looking figures
viewer.setViewStyle({"style": "outline", "width": 0.05})
viewer.addModel(thymine_xyz)
# visualize with the sticks and spheres
viewer.setStyle({"stick":{},"sphere": {"scale":0.25}})
# rotate for a better initial view
viewer.rotate(-90, "y")
viewer.show()
# Out:
# <div id="3dmolviewer_17079254400877438"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17079254400877438" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17079254400877438 = null;
# var warn = document.getElementById("3dmolwarning_17079254400877438");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17079254400877438 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17079254400877438"),{backgroundColor:"white"});
# viewer_17079254400877438.zoomTo();
# 	viewer_17079254400877438.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17079254400877438.addModel("15\n*\n C     0.095722    -0.037785    -1.093615\n C    -0.011848     1.408694    -1.113404\n C    -0.204706     2.048475     0.052807\n N    -0.302595     1.390520     1.249226\n C    -0.214596     0.023933     1.378238\n N    -0.017387    -0.607231     0.171757\n O     0.270287    -0.735594    -2.076393\n C     0.098029     2.096194    -2.424990\n H     1.052976     1.874860    -2.891573\n H     0.002157     3.170639    -2.310554\n H    -0.671531     1.743694    -3.104794\n O    -0.301905    -0.554734     2.440234\n H    -0.292790     3.119685     0.106201\n H     0.053626    -1.612452     0.215637\n H    -0.446827     1.892203     2.107092\n");
# 	viewer_17079254400877438.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17079254400877438.rotate(-90,"y");
# viewer_17079254400877438.render();
# });
# </script>

# %% [markdown]
# This creates a dynamic view which can be rotated and zoomed in and out.
#
# This functionality is available through `VeloxChem` using `molecule.show()`:

# %%
molecule = vlx.Molecule.read_xyz_string(thymine_xyz)
molecule.show()
# Out:
# <div id="3dmolviewer_17079255609387927"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17079255609387927" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17079255609387927 = null;
# var warn = document.getElementById("3dmolwarning_17079255609387927");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17079255609387927 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17079255609387927"),{backgroundColor:"white"});
# viewer_17079255609387927.zoomTo();
# 	viewer_17079255609387927.addModel("15\n\nC              0.095722000000        -0.037785000000        -1.093615000000\nC             -0.011848000000         1.408694000000        -1.113404000000\nC             -0.204706000000         2.048475000000         0.052807000000\nN             -0.302595000000         1.390520000000         1.249226000000\nC             -0.214596000000         0.023933000000         1.378238000000\nN             -0.017387000000        -0.607231000000         0.171757000000\nO              0.270287000000        -0.735594000000        -2.076393000000\nC              0.098029000000         2.096194000000        -2.424990000000\nH              1.052976000000         1.874860000000        -2.891573000000\nH              0.002157000000         3.170639000000        -2.310554000000\nH             -0.671531000000         1.743694000000        -3.104794000000\nO             -0.301905000000        -0.554734000000         2.440234000000\nH             -0.292790000000         3.119685000000         0.106201000000\nH              0.053626000000        -1.612452000000         0.215637000000\nH             -0.446827000000         1.892203000000         2.107092000000\n");
# 	viewer_17079255609387927.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17079255609387927.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17079255609387927.zoomTo();
# viewer_17079255609387927.render();
# });
# </script>

# %% [markdown]
# Alternatively, PDF-files can be loaded directly from the PDB-library, and illustrated with different models (here looking at an [XRD structure](https://www.rcsb.org/structure/6w1o) of [photosystem II](https://www.pnas.org/doi/full/10.1073/pnas.2000529117)):

# %%
viewer = py3Dmol.view(
    query="pdb:6W1O", viewergrid=(1, 3), width=800, height=300, linked=False
)
viewer.setStyle({"cartoon": {"color": "spectrum"}}, viewer=(0, 1))
viewer.setStyle({"cartoon": {}}, viewer=(0, 2))
viewer.addStyle({"elem": "Mn"}, {"sphere": {"color": "red"}}, viewer=(0, 2))
viewer.addStyle({"elem": "Ca"}, {"sphere": {"color": "yellow"}}, viewer=(0, 2))
viewer.show()
# Out:
# <div id="3dmolviewer_16569392185167198"  style="position: relative; width: 800px; height: 300px">
#         <p id="3dmolwarning_16569392185167198" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16569392185167198 = null;
# var warn = document.getElementById("3dmolwarning_16569392185167198");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_16569392185167198 = null;
# viewergrid_16569392185167198 = $3Dmol.createViewerGrid($("#3dmolviewer_16569392185167198"),{rows: 1, cols: 3, control_all: false},{backgroundColor:"white"});
# viewer_16569392185167198 = viewergrid_16569392185167198[0][0];
# $3Dmol.download("pdb:6W1O", viewergrid_16569392185167198[0][0], {}, function() {
# $3Dmol.download("pdb:6W1O", viewergrid_16569392185167198[0][1], {}, function() {
# $3Dmol.download("pdb:6W1O", viewergrid_16569392185167198[0][2], {}, function() {
# viewergrid_16569392185167198[0][0].zoomTo();viewergrid_16569392185167198[0][1].zoomTo();viewergrid_16569392185167198[0][2].zoomTo();	viewergrid_16569392185167198[0][1].setStyle({"cartoon": {"color": "spectrum"}});
# 	viewergrid_16569392185167198[0][2].setStyle({"cartoon": {}});
# 	viewergrid_16569392185167198[0][2].addStyle({"elem": "Mn"},{"sphere": {"color": "red"}});
# 	viewergrid_16569392185167198[0][2].addStyle({"elem": "Ca"},{"sphere": {"color": "yellow"}});
# viewergrid_16569392185167198[0][2].render();
# viewergrid_16569392185167198[0][1].render();
# viewergrid_16569392185167198[0][0].render();
# })
# })
# })
# });
# </script>

# %% [markdown]
# Here we illustrate this by line structure, and more cartoonish image with and without coloring different strands differently. To the right we see white ribbons with manganese and calcium atoms colored in red and yellow, respectively. These shows the position of the oxygen-evolving complex of photosystem II, which is the site of water-splitting and oxygen generation.
