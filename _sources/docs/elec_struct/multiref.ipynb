# %% [markdown]
# # Multireference methods
#
# In this section we will describe commonly adopted multireference methods.
#
# - [Multiconfigurational methods](mcscf) <br>
# A description of dynamic versus static/strong correlation, and a presentation and implementation of multiconfigurational self-consistent field theory.
# - [Multiconfigurational pair-density functional theory](mcpdft) <br>
# An explanation of a way to generalize of DFT to a multiconfigurational wavefunction.
