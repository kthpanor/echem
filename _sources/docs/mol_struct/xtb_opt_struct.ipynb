# %% [markdown]
# (sec:structopt-methods)=
# # Optimization methods
#
# The first class of special points on the PES that we will discuss are local energy minima. These correspond to equilibrium molecular structures and are characterized by a vanishing first order energy derivative combined with a Hessian matrix which has only positive eigenvalues. The procedure to determine a local minimum (i.e. finding the coordinates that minimize the energy) is called a structure optimization.
#
# ```{figure} ../../img/pes/PES.png
# ```
# In practical terms, the ingredients to perform a geometry optimization include: (1) the initial molecular coordinates, (2) a choice of coordinate system, (3) the energy at a specific geometry $E(\mathbf{x})$, (4) the gradient $\mathbf{g}(\mathbf{x})=\nabla E(\mathbf{x})$, (5) the Hessian, and (6) a procedure to update the coordinates and Hessian and move on the potential energy surface towards lower energy.
#
# Having addressed [the issue of coordinate system](coord), the remaining question is what procedure to use to move along the potential energy surface and arrive at a local energy minimum. There are several iterative methods to do this, some of which need only information on the energy gradient (e.g. gradient-descent, conjugate gradient), while others take into account also the Hessian (Newton--Raphson, quasi-Newton). For a detailed review of minimization techniques, see {cite}`Snyman2005`.
#
# ## Gradient descent
#
# The simplest optimization procedure is to repeatedly take a step in the direction opposite to the local gradient
# %
# \begin{equation}
# \mathbf{x}_{i+1} = \mathbf{x}_i - k_i\mathbf{g}(\mathbf{x}_i) \nonumber
# \end{equation}
# where by $\mathbf{x}_{i+1}$ we denote the new coordinates (in a generic coordinate system -- either Cartesian or internal coordinates), $\mathbf{x}_i$ are the coordinates at the previous step $i$, $\nabla E$ is the energy gradient and $k_i$ is the step size. The step size can either be kept constant, or adjusted at each iteration, e.g. by the line search procedure.
#
# The gradient-descent method is simple to implement and is guaranteed to converge, but has the disadvantage that it requires many steps and becomes slow when close to the minimum where the gradient is small. It always converges to a local minimum, given enough steps.

# %% [markdown]
# ### Implementation
# Let's implement the gradient descent method. We will need to set up a molecule, an SCF driver and a gradient driver.

# %%
# Import section
import veloxchem as vlx
import py3Dmol as p3d
from veloxchem.veloxchemlib import bohr_in_angstroms
import numpy as np
from matplotlib import pyplot as plt
# Out:
# * Warning * Environment variable OMP_NUM_THREADS not set.
# * Warning * Setting OMP_NUM_THREADS to 8.

# %%
# Define the molecule
molecule_xyz = """6
ethylene molecule from https://molview.org/
C   -0.6672    0.0000    0.0000
C    0.6672    0.0000    0.0000
H   -1.2213   -0.9290    0.0708
H   -1.2212    0.9290   -0.0708
H    1.2213    0.9290   -0.0708
H    1.2213   -0.9290    0.0708
"""
molecule = vlx.Molecule.from_xyz_string(molecule_xyz)

# %%
view = p3d.view(linked=True, viewergrid=(1,1),width=400,height=300)
view.addModel(molecule_xyz, 'xyz', viewer=(0,0))
view.setViewStyle({"style": "outline", "width": 0.05})
view.setStyle({'stick': {}, 'sphere': {'scale':0.25}})
view.rotate(-90, "x")
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_1684136039189475"  style="position: relative; width: 400px; height: 300px">
#         <p id="3dmolwarning_1684136039189475" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_1684136039189475 = null;
# var warn = document.getElementById("3dmolwarning_1684136039189475");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_1684136039189475 = null;
# viewergrid_1684136039189475 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_1684136039189475"),{rows: 1, cols: 1, control_all: true},{backgroundColor:"white"});
# viewer_1684136039189475 = viewergrid_1684136039189475[0][0];
# viewergrid_1684136039189475[0][0].zoomTo();	viewergrid_1684136039189475[0][0].addModel("6\nethylene molecule from https://molview.org/\nC   -0.6672    0.0000    0.0000\nC    0.6672    0.0000    0.0000\nH   -1.2213   -0.9290    0.0708\nH   -1.2212    0.9290   -0.0708\nH    1.2213    0.9290   -0.0708\nH    1.2213   -0.9290    0.0708\n","xyz");
# 	viewergrid_1684136039189475[0][0].setViewStyle({"style": "outline", "width": 0.05});
# 	viewergrid_1684136039189475[0][0].setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewergrid_1684136039189475[0][0].rotate(-90,"x");
# 	viewergrid_1684136039189475[0][0].zoomTo();
# viewergrid_1684136039189475[0][0].render();
# });
# </script>

# %%
# XTB Energy driver
xtb_drv = vlx.XtbDriver()

# Gradient driver
xtb_grad_driver = vlx.XtbGradientDriver()

# %% [markdown]
# Now, write your own routine to run one gradient descent iteration:
# ```python
# def gradient_descent_iteration(coordinates, gradient, step):
#     ...
#     return new_coordinates
# ```

# %%
def gradient_descent_iteration(coordinates, gradient, step):
    new_coordinates = coordinates - step * gradient
    return new_coordinates

# %% [markdown]
# And the routine that runs the optimization:
# ```python
# def gradient_descent(molecule, energy_driver, gradient_driver,
#                      step=0.1, threshold=1e-3, max_iter=10):
#
#     # create ostream for xtb driver
#     ostream = vlx.OutputStream()
#
#     iteration = 0
#     grad_norm = 100
#
#     # save atom labels (symbols)
#     labels = molecule.get_labels()
#
#     # initial atomic coordinates
#     old_coords = molecule.get_coordinates()
#
#     energy_driver.compute(molecule, ostream)
#     old_energy = energy_driver.get_energy()
#
#     gradient_driver.compute(molecule, energy_driver)
#     old_gradient = gradient_driver.get_gradient()
#
#     print("Starting gradient descent:\n")
#     text = "Iteration     Energy (H)      "
#     text += "Max. displacement (bohr)    Gradient norm (H/bohr)"
#     print(text)
#     energies = [old_energy]
#     iterations = [0]
#
#     while (grad_norm >= threshold) and (iteration <= max_iter):
#         ...
#         ...
#         ...
#
#     if iteration <= max_iter:
#         text = "\n   *** Gradient Descent converged in "
#         text += "%d iteration(s). *** " % iteration
#         print(text)
#     else:
#         print("\n   !!! Gradient Descent did not converge  !!! ")
#         new_molecule = None
#     return new_molecule, iterations, energies
# ```

# %%
def gradient_descent(molecule, energy_driver, gradient_driver,
                     step=0.1, threshold=1e-3, max_iter=10):
    
    # create ostream for xtb driver
    ostream = vlx.OutputStream()
    ostream.mute()
    
    iteration = 0
    grad_norm = 100
    
    # save atom labels (symbols)
    labels = molecule.get_labels()
    
    # initial atomic coordinates
    old_coords = molecule.get_coordinates()
    
    energy_driver.compute(molecule, ostream)
    old_energy = energy_driver.get_energy()
    
    gradient_driver.compute(molecule, energy_driver)
    old_gradient = gradient_driver.get_gradient()
    
    print("Starting gradient descent:\n")
    text = "Iteration     Energy (H)      "
    text += "Max. displacement (bohr)    Gradient norm (H/bohr)"
    print(text)
    energies = [old_energy]
    iterations = [0]
    
    while (grad_norm >= threshold) and (iteration <= max_iter):
        coords = gradient_descent_iteration(old_coords, old_gradient, step)
        
        # calculate the energy and gradient corresponding to the new coordinates
        new_molecule = vlx.molecule.Molecule(labels, coords, units='au')
        
        energy_driver.compute(new_molecule, ostream)
        energy = energy_driver.get_energy()
        energies.append(energy)
        
        gradient_driver.compute(new_molecule, energy_driver)
        gradient = gradient_driver.get_gradient()
        grad_norm = np.linalg.norm(gradient)
        
        displacement = old_coords - coords
        max_disp = np.amax(abs(displacement))
        
        # calculate energy difference
        delta_e = abs(energy - old_energy)
        text = "   %3d.  %15.7f      " % (iteration, energy, )
        text += "%15.7f          %15.7f" % (max_disp, grad_norm)
        print(text)
        
        # save 
        old_energy = energy
        old_gradient = gradient
        old_coords = coords
        iteration += 1
        iterations.append(iteration)
        
    if iteration <= max_iter:
        text = "\n   *** Gradient Descent converged in "
        text += "%d iteration(s). *** " % iteration
        print(text)
    else:
        print("\n   !!! Gradient Descent did not converge  !!! ")
        new_molecule = None
    return new_molecule, iterations, energies

# %%
opt_mol, gd_iterations, gd_energies = gradient_descent(molecule,
                                                       xtb_drv, xtb_grad_driver,
                                                       step = 0.05,
                                                       threshold=1e-2,
                                                       max_iter=50)
# Out:
#
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3729735 -0.637297E+01  0.525E+00    5.52       0.0  T
#    2     -6.3881357 -0.151621E-01  0.313E+00    5.50       1.0  T
#    3     -6.3885985 -0.462845E-03  0.798E-01    5.47       1.0  T
#    4     -6.3887933 -0.194762E-03  0.803E-02    5.47       1.0  T
#    5     -6.3887930  0.267460E-06  0.136E-02    5.47       3.0  T
#    6     -6.3887934 -0.434522E-06  0.180E-03    5.47      22.7  T
#    7     -6.3887934 -0.158985E-08  0.110E-03    5.47      37.1  T
#    8     -6.3887934 -0.225860E-08  0.225E-04    5.47     181.1  T
#    9     -6.3887934 -0.117772E-09  0.113E-06    5.47   35991.9  T
#
#    *** convergence criteria satisfied after 9 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6072685             -16.5246
#          2        2.0000           -0.5472525             -14.8915
#          3        2.0000           -0.5060032             -13.7690
#          4        2.0000           -0.4684738             -12.7478
#          5        2.0000           -0.4333463             -11.7920
#          6        2.0000           -0.4129780             -11.2377 (HOMO)
#          7                         -0.2120712              -5.7707 (LUMO)
#          8                          0.1284580               3.4955
#          9                          0.1619453               4.4068
#         10                          0.1800861               4.9004
#         11                          0.4306229              11.7178
#         12                          0.5463529              14.8670
#       -------------------------------------------------------------
#                   HL-Gap            0.2009069 Eh            5.4670 eV
#              Fermi-level           -0.3125246 Eh           -8.5042 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.391 sec
#  SCC setup                      ...        0 min,  0.032 sec (  8.137%)
#  Dispersion                     ...        0 min,  0.039 sec ( 10.024%)
#  classical contributions        ...        0 min,  0.015 sec (  3.752%)
#  integral evaluation            ...        0 min,  0.109 sec ( 27.988%)
#  iterations                     ...        0 min,  0.193 sec ( 49.436%)
#  molecular gradient             ...        0 min,  0.002 sec (  0.515%)
#  printout                       ...        0 min,  0.000 sec (  0.113%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.270546396369 Eh    ::
#          :: gradient norm              0.029319660251 Eh/a0 ::
#          :: HOMO-LUMO gap              5.466953921291 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.388793442110 Eh    ::
#          :: -> isotropic ES            0.001306992522 Eh    ::
#          :: -> anisotropic ES          0.001943470317 Eh    ::
#          :: -> anisotropic XC          0.007977199023 Eh    ::
#          :: -> dispersion             -0.001447041755 Eh    ::
#          :: repulsion energy           0.118247009792 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge              -0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.667200000000        0.000000000000        0.000000000000
#                            C           0.667200000000        0.000000000000        0.000000000000
#                            H          -1.221300000000       -0.929000000000        0.070800000000
#                            H          -1.221200000000        0.929000000000       -0.070800000000
#                            H           1.221300000000        0.929000000000       -0.070800000000
#                            H           1.221300000000       -0.929000000000        0.070800000000
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.019037543196        0.000028275934       -0.000002154937
#                            C           0.019013662058       -0.000003297705        0.000000251321
#                            H          -0.000175348261       -0.005812418354        0.000442970096
#                            H          -0.000152854435        0.005787209890       -0.000441048935
#                            H           0.000176659656        0.005810435947       -0.000442819015
#                            H           0.000175424178       -0.005810205711        0.000442801469
#
#
# Starting gradient descent:
#
# Iteration     Energy (H)      Max. displacement (bohr)    Gradient norm (H/bohr)
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3890788 -0.638908E+01  0.360E-03    5.48       0.0  T
#    2     -6.3890788 -0.533157E-08  0.199E-03    5.48      20.5  T
#    3     -6.3890788 -0.146616E-09  0.480E-04    5.48      85.1  T
#    4     -6.3890788 -0.514744E-10  0.499E-05    5.48     818.5  T
#
#    *** convergence criteria satisfied after 4 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6073853             -16.5278
#          2        2.0000           -0.5472805             -14.8923
#          3        2.0000           -0.5060465             -13.7702
#          4        2.0000           -0.4685323             -12.7494
#          5        2.0000           -0.4332564             -11.7895
#          6        2.0000           -0.4131394             -11.2421 (HOMO)
#          7                         -0.2118034              -5.7635 (LUMO)
#          8                          0.1284313               3.4948
#          9                          0.1613673               4.3910
#         10                          0.1802135               4.9039
#         11                          0.4305607              11.7162
#         12                          0.5491391              14.9428
#       -------------------------------------------------------------
#                   HL-Gap            0.2013360 Eh            5.4786 eV
#              Fermi-level           -0.3124714 Eh           -8.5028 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.037 sec
#  SCC setup                      ...        0 min,  0.006 sec ( 15.205%)
#  Dispersion                     ...        0 min,  0.000 sec (  0.239%)
#  classical contributions        ...        0 min,  0.019 sec ( 52.114%)
#  integral evaluation            ...        0 min,  0.000 sec (  1.281%)
#  iterations                     ...        0 min,  0.010 sec ( 27.017%)
#  molecular gradient             ...        0 min,  0.001 sec (  2.887%)
#  printout                       ...        0 min,  0.000 sec (  0.990%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.270588259940 Eh    ::
#          :: gradient norm              0.027801062286 Eh/a0 ::
#          :: HOMO-LUMO gap              5.478631548767 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.389078776984 Eh    ::
#          :: -> isotropic ES            0.001303805960 Eh    ::
#          :: -> anisotropic ES          0.001942516274 Eh    ::
#          :: -> anisotropic XC          0.007970439160 Eh    ::
#          :: -> dispersion             -0.001447214156 Eh    ::
#          :: repulsion energy           0.118490481142 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge              -0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.666696288299       -0.000000748149        0.000000057017
#                            C           0.666696920167        0.000000087254       -0.000000006650
#                            H          -1.221295360485       -0.928846210033        0.070788279516
#                            H          -1.221195955646        0.928846877021       -0.070788330348
#                            H           1.221295325787        0.928846262486       -0.070788283513
#                            H           1.221295358476       -0.928846268577        0.070788283978
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.017849113240        0.000018442639       -0.000001378828
#                            C           0.017825786171        0.000005494041       -0.000000445410
#                            H          -0.000222605066       -0.005828912628        0.000444227141
#                            H          -0.000200687476        0.005804824124       -0.000442391333
#                            H           0.000223941281        0.005827099456       -0.000444088957
#                            H           0.000222678331       -0.005826947632        0.000444077387
#
#
#      0.       -6.2705883            0.0009519                0.0278012
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3893514 -0.638935E+01  0.342E-03    5.49       0.0  T
#    2     -6.3893514 -0.454829E-08  0.190E-03    5.49      21.5  T
#    3     -6.3893514 -0.129392E-09  0.443E-04    5.49      92.3  T
#    4     -6.3893514 -0.460583E-10  0.486E-05    5.49     840.2  T
#
#    *** convergence criteria satisfied after 4 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6074952             -16.5308
#          2        2.0000           -0.5473082             -14.8930
#          3        2.0000           -0.5060874             -13.7713
#          4        2.0000           -0.4685877             -12.7509
#          5        2.0000           -0.4331723             -11.7872
#          6        2.0000           -0.4132910             -11.2462 (HOMO)
#          7                         -0.2115518              -5.7566 (LUMO)
#          8                          0.1284201               3.4945
#          9                          0.1608383               4.3766
#         10                          0.1803500               4.9076
#         11                          0.4305203              11.7151
#         12                          0.5517655              15.0143
#       -------------------------------------------------------------
#                   HL-Gap            0.2017392 Eh            5.4896 eV
#              Fermi-level           -0.3124214 Eh           -8.5014 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.024 sec
#  SCC setup                      ...        0 min,  0.003 sec ( 12.203%)
#  Dispersion                     ...        0 min,  0.000 sec (  0.459%)
#  classical contributions        ...        0 min,  0.017 sec ( 73.448%)
#  integral evaluation            ...        0 min,  0.000 sec (  1.744%)
#  iterations                     ...        0 min,  0.002 sec (  6.575%)
#  molecular gradient             ...        0 min,  0.001 sec (  3.806%)
#  printout                       ...        0 min,  0.000 sec (  1.436%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.270625918184 Eh    ::
#          :: gradient norm              0.026388555998 Eh/a0 ::
#          :: HOMO-LUMO gap              5.489601747851 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.389351448940 Eh    ::
#          :: -> isotropic ES            0.001300886697 Eh    ::
#          :: -> anisotropic ES          0.001941508435 Eh    ::
#          :: -> anisotropic XC          0.007963829964 Eh    ::
#          :: -> dispersion             -0.001447374651 Eh    ::
#          :: repulsion energy           0.118725494900 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge              -0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.666224021101       -0.000001236120        0.000000093499
#                            C           0.666225270177       -0.000000058113        0.000000005135
#                            H          -1.221289470608       -0.928691983647        0.070776525772
#                            H          -1.221190645684        0.928693287989       -0.070776625177
#                            H           1.221289400556        0.928692084074       -0.070776533426
#                            H           1.221289466661       -0.928692094183        0.070776534196
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.016733318092        0.000017539459       -0.000001299168
#                            C           0.016710531287        0.000005401430       -0.000000449179
#                            H          -0.000264477186       -0.005838884024        0.000444987117
#                            H          -0.000243046518        0.005815665020       -0.000443217482
#                            H           0.000265832990        0.005837228450       -0.000444860944
#                            H           0.000264477518       -0.005836950335        0.000444839656
#
#
#      1.       -6.2706259            0.0008925                0.0263887
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3896122 -0.638961E+01  0.326E-03    5.50       0.0  T
#    2     -6.3896122 -0.387042E-08  0.181E-03    5.50      22.5  T
#    3     -6.3896122 -0.114556E-09  0.407E-04    5.50     100.2  T
#    4     -6.3896122 -0.411244E-10  0.473E-05    5.50     862.3  T
#
#    *** convergence criteria satisfied after 4 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6075990             -16.5336
#          2        2.0000           -0.5473355             -14.8938
#          3        2.0000           -0.5061263             -13.7724
#          4        2.0000           -0.4686404             -12.7524
#          5        2.0000           -0.4330935             -11.7851
#          6        2.0000           -0.4134333             -11.2501 (HOMO)
#          7                         -0.2113155              -5.7502 (LUMO)
#          8                          0.1284232               3.4946
#          9                          0.1603550               4.3635
#         10                          0.1804945               4.9115
#         11                          0.4304999              11.7145
#         12                          0.5542404              15.0816
#       -------------------------------------------------------------
#                   HL-Gap            0.2021178 Eh            5.4999 eV
#              Fermi-level           -0.3123744 Eh           -8.5001 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.047 sec
#  SCC setup                      ...        0 min,  0.009 sec ( 19.806%)
#  Dispersion                     ...        0 min,  0.000 sec (  0.165%)
#  classical contributions        ...        0 min,  0.009 sec ( 18.465%)
#  integral evaluation            ...        0 min,  0.000 sec (  0.922%)
#  iterations                     ...        0 min,  0.019 sec ( 40.752%)
#  molecular gradient             ...        0 min,  0.009 sec ( 18.634%)
#  printout                       ...        0 min,  0.000 sec (  0.746%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.270659865300 Eh    ::
#          :: gradient norm              0.025076081621 Eh/a0 ::
#          :: HOMO-LUMO gap              5.499905197728 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.389612172597 Eh    ::
#          :: -> isotropic ES            0.001298205561 Eh    ::
#          :: -> anisotropic ES          0.001940455400 Eh    ::
#          :: -> anisotropic XC          0.007957364608 Eh    ::
#          :: -> dispersion             -0.001447524323 Eh    ::
#          :: repulsion energy           0.118952271485 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge               0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.665781276572       -0.000001700194        0.000000127874
#                            C           0.665783128560       -0.000000201028        0.000000017020
#                            H          -1.221282472843       -0.928537493429        0.070764751920
#                            H          -1.221184214950        0.928539412119       -0.070764898148
#                            H           1.221282366918        0.928537637660       -0.070764762912
#                            H           1.221282468887       -0.928537655128        0.070764764246
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.015686336161        0.000016678746       -0.000001223474
#                            C           0.015664076247        0.000005309671       -0.000000452284
#                            H          -0.000301309779       -0.005842739315        0.000445280998
#                            H          -0.000280347634        0.005820351320       -0.000443574564
#                            H           0.000302680324        0.005841230430       -0.000445166005
#                            H           0.000301237003       -0.005840830852        0.000445135329
#
#
#      2.       -6.2706599            0.0008367                0.0250762
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3898616 -0.638986E+01  0.310E-03    5.51       0.0  T
#    2     -6.3898616 -0.328515E-08  0.173E-03    5.51      23.6  T
#    3     -6.3898616 -0.101828E-09  0.374E-04    5.51     109.1  T
#    4     -6.3898616 -0.366391E-10  0.461E-05    5.51     884.8  T
#
#    *** convergence criteria satisfied after 4 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6076968             -16.5363
#          2        2.0000           -0.5473626             -14.8945
#          3        2.0000           -0.5061631             -13.7734
#          4        2.0000           -0.4686904             -12.7537
#          5        2.0000           -0.4330198             -11.7831
#          6        2.0000           -0.4135668             -11.2537 (HOMO)
#          7                         -0.2110935              -5.7441 (LUMO)
#          8                          0.1284396               3.4950
#          9                          0.1599143               4.3515
#         10                          0.1806464               4.9156
#         11                          0.4304979              11.7144
#         12                          0.5565719              15.1451
#       -------------------------------------------------------------
#                   HL-Gap            0.2024734 Eh            5.5096 eV
#              Fermi-level           -0.3123302 Eh           -8.4989 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.005 sec
#  SCC setup                      ...        0 min,  0.002 sec ( 36.733%)
#  Dispersion                     ...        0 min,  0.000 sec (  1.209%)
#  classical contributions        ...        0 min,  0.000 sec (  0.470%)
#  integral evaluation            ...        0 min,  0.000 sec (  8.721%)
#  iterations                     ...        0 min,  0.002 sec ( 31.146%)
#  molecular gradient             ...        0 min,  0.001 sec ( 14.563%)
#  printout                       ...        0 min,  0.000 sec (  6.006%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.270690537453 Eh    ::
#          :: gradient norm              0.023857858137 Eh/a0 ::
#          :: HOMO-LUMO gap              5.509580645067 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.389861623404 Eh    ::
#          :: -> isotropic ES            0.001295746966 Eh    ::
#          :: -> anisotropic ES          0.001939362349 Eh    ::
#          :: -> anisotropic XC          0.007951039801 Eh    ::
#          :: -> dispersion             -0.001447663837 Eh    ::
#          :: repulsion energy           0.119171050183 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge               0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.665366233991       -0.000002141495        0.000000160246
#                            C           0.665368674951       -0.000000341516        0.000000028987
#                            H          -1.221274500530       -0.928382901204        0.070752970292
#                            H          -1.221176797271        0.928385412255       -0.070753161670
#                            H           1.221274358341        0.928383085359       -0.070752984327
#                            H           1.221274498500       -0.928383113399        0.070752986472
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.014704462711        0.000015858116       -0.000001151530
#                            C           0.014682716688        0.000005218860       -0.000000454767
#                            H          -0.000333460905       -0.005840957537        0.000445145290
#                            H          -0.000312949816        0.005819364184       -0.000443499250
#                            H           0.000334841713        0.005839585115       -0.000445040697
#                            H           0.000333315030       -0.005839068738        0.000445000953
#
#
#      3.       -6.2706905            0.0007843                0.0238580
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3901004 -0.639010E+01  0.296E-03    5.52       0.0  T
#    2     -6.3901004 -0.278112E-08  0.166E-03    5.52      24.7  T
#    3     -6.3901004 -0.909175E-10  0.343E-04    5.52     119.0  T
#    4     -6.3901004 -0.325482E-10  0.450E-05    5.52     907.9  T
#
#    *** convergence criteria satisfied after 4 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6077892             -16.5388
#          2        2.0000           -0.5473893             -14.8952
#          3        2.0000           -0.5061981             -13.7744
#          4        2.0000           -0.4687381             -12.7550
#          5        2.0000           -0.4329509             -11.7812
#          6        2.0000           -0.4136922             -11.2571 (HOMO)
#          7                         -0.2108850              -5.7385 (LUMO)
#          8                          0.1284684               3.4958
#          9                          0.1595134               4.3406
#         10                          0.1808050               4.9200
#         11                          0.4305127              11.7148
#         12                          0.5587679              15.2048
#       -------------------------------------------------------------
#                   HL-Gap            0.2028072 Eh            5.5187 eV
#              Fermi-level           -0.3122886 Eh           -8.4978 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.072 sec
#  SCC setup                      ...        0 min,  0.008 sec ( 11.282%)
#  Dispersion                     ...        0 min,  0.000 sec (  0.095%)
#  classical contributions        ...        0 min,  0.000 sec (  0.034%)
#  integral evaluation            ...        0 min,  0.000 sec (  0.586%)
#  iterations                     ...        0 min,  0.002 sec (  2.170%)
#  molecular gradient             ...        0 min,  0.061 sec ( 85.172%)
#  printout                       ...        0 min,  0.000 sec (  0.564%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.270718319140 Eh    ::
#          :: gradient norm              0.022728240930 Eh/a0 ::
#          :: HOMO-LUMO gap              5.518665059640 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.390100439173 Eh    ::
#          :: -> isotropic ES            0.001293496175 Eh    ::
#          :: -> anisotropic ES          0.001938234058 Eh    ::
#          :: -> anisotropic XC          0.007944852140 Eh    ::
#          :: -> dispersion             -0.001447793825 Eh    ::
#          :: repulsion energy           0.119382084307 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge               0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.664977170662       -0.000002561083        0.000000190714
#                            C           0.664980186998       -0.000000479601        0.000000041020
#                            H          -1.221265677534       -0.928228356123        0.070741192255
#                            H          -1.221168516975        0.928231438510       -0.070741427185
#                            H           1.221265498811        0.928228576591       -0.070741209057
#                            H           1.221265679364       -0.928228618293        0.070741212254
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.013784117754        0.000015075363       -0.000001083134
#                            C           0.013762872986        0.000005129075       -0.000000456666
#                            H          -0.000361267400       -0.005833986607        0.000444614129
#                            H          -0.000341190769        0.005813153493       -0.000443025827
# ...
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3941724 -0.639417E+01  0.127E-03    5.64       0.0  T
#    2     -6.3941724 -0.397922E-10  0.747E-04    5.64      54.6  T
#    3     -6.3941724 -0.204414E-10  0.480E-05    5.64     850.1  T
#
#    *** convergence criteria satisfied after 3 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6090697             -16.5736
#          2        2.0000           -0.5480108             -14.9121
#          3        2.0000           -0.5067060             -13.7882
#          4        2.0000           -0.4695190             -12.7763
#          5        2.0000           -0.4321059             -11.7582
#          6        2.0000           -0.4153076             -11.3011 (HOMO)
#          7                         -0.2082065              -5.6656 (LUMO)
#          8                          0.1316580               3.5826
#          9                          0.1567894               4.2665
#         10                          0.1861776               5.0661
#         11                          0.4339640              11.8088
#         12                          0.5879606              15.9992
#       -------------------------------------------------------------
#                   HL-Gap            0.2071012 Eh            5.6355 eV
#              Fermi-level           -0.3117571 Eh           -8.4833 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.162 sec
#  SCC setup                      ...        0 min,  0.005 sec (  2.891%)
#  Dispersion                     ...        0 min,  0.001 sec (  0.429%)
#  classical contributions        ...        0 min,  0.000 sec (  0.016%)
#  integral evaluation            ...        0 min,  0.079 sec ( 48.629%)
#  iterations                     ...        0 min,  0.077 sec ( 47.281%)
#  molecular gradient             ...        0 min,  0.001 sec (  0.485%)
#  printout                       ...        0 min,  0.000 sec (  0.217%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.271030910825 Eh    ::
#          :: gradient norm              0.010031766323 Eh/a0 ::
#          :: HOMO-LUMO gap              5.635509737403 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.394172416514 Eh    ::
#          :: -> isotropic ES            0.001275673656 Eh    ::
#          :: -> anisotropic ES          0.001903482169 Eh    ::
#          :: -> anisotropic XC          0.007814393165 Eh    ::
#          :: -> dispersion             -0.001449276499 Eh    ::
#          :: repulsion energy           0.123141470765 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge              -0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.660021967685       -0.000008469449        0.000000550275
#                            C           0.660036722031       -0.000003505145        0.000000362320
#                            H          -1.220969739349       -0.924256566982        0.070438496168
#                            H          -1.220884273731        0.924269828874       -0.070439511180
#                            H           1.220968706991        0.924257056127       -0.070438533446
#                            H           1.220970551743       -0.924258343425        0.070438635863
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.002550316329        0.000002883520       -0.000000080465
#                            C           0.002539098974        0.000003141697       -0.000000378722
#                            H          -0.000251320182       -0.004664679231        0.000355506048
#                            H          -0.000238945382        0.004656220502       -0.000354848851
#                            H           0.000252041977        0.004664708634       -0.000355508289
#                            H           0.000249440941       -0.004662275121        0.000355310279
#
#
#     32.       -6.2710309            0.0002359                0.0100319
#
#           ...................................................
#           :                      SETUP                      :
#           :.................................................:
#           :  # basis functions                  12          :
#           :  # atomic orbitals                  12          :
#           :  # shells                            8          :
#           :  # electrons                        12          :
#           :  max. iterations                   280          :
#           :  Hamiltonian                  GFN2-xTB          :
#           :  restarted?                       true          :
#           :  GBSA solvation                  false          :
#           :  PC potential                    false          :
#           :  electronic temp.          300.0000000     K    :
#           :  accuracy                    1.0000000          :
#           :  -> integral cutoff          0.2500000E+02      :
#           :  -> integral neglect         0.1000000E-07      :
#           :  -> SCF convergence          0.1000000E-05 Eh   :
#           :  -> wf. convergence          0.1000000E-03 e    :
#           :  Broyden damping             0.4000000          :
#           ...................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1     -6.3942627 -0.639426E+01  0.125E-03    5.64       0.0  T
#    2     -6.3942627 -0.403801E-10  0.735E-04    5.64      55.6  T
#    3     -6.3942627 -0.197922E-10  0.471E-05    5.64     866.8  T
#
#    *** convergence criteria satisfied after 3 iterations ***
#
#          #    Occupation            Energy/Eh            Energy/eV
#       -------------------------------------------------------------
#          1        2.0000           -0.6090904             -16.5742
#          2        2.0000           -0.5480288             -14.9126
#          3        2.0000           -0.5067145             -13.7884
#          4        2.0000           -0.4695362             -12.7767
#          5        2.0000           -0.4320954             -11.7579
#          6        2.0000           -0.4153300             -11.3017 (HOMO)
#          7                         -0.2081700              -5.6646 (LUMO)
#          8                          0.1317981               3.5864
#          9                          0.1568304               4.2676
#         10                          0.1863661               5.0713
#         11                          0.4341177              11.8129
#         12                          0.5883872              16.0108
#       -------------------------------------------------------------
#                   HL-Gap            0.2071600 Eh            5.6371 eV
#              Fermi-level           -0.3117500 Eh           -8.4831 eV
#
#  SCC (total)                   0 d,  0 h,  0 min,  0.763 sec
#  SCC setup                      ...        0 min,  0.009 sec (  1.236%)
#  Dispersion                     ...        0 min,  0.054 sec (  7.109%)
#  classical contributions        ...        0 min,  0.023 sec (  3.005%)
#  integral evaluation            ...        0 min,  0.097 sec ( 12.653%)
#  iterations                     ...        0 min,  0.300 sec ( 39.272%)
#  molecular gradient             ...        0 min,  0.280 sec ( 36.650%)
#  printout                       ...        0 min,  0.000 sec (  0.055%)
#
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          ::                     SUMMARY                     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#          :: total energy              -6.271035901184 Eh    ::
#          :: gradient norm              0.009867026227 Eh/a0 ::
#          :: HOMO-LUMO gap              5.637111549991 eV    ::
#          ::.................................................::
#          :: SCC energy                -6.394262749459 Eh    ::
#          :: -> isotropic ES            0.001275785395 Eh    ::
#          :: -> anisotropic ES          0.001902341680 Eh    ::
#          :: -> anisotropic XC          0.007810891332 Eh    ::
#          :: -> dispersion             -0.001449290889 Eh    ::
#          :: repulsion energy           0.123226813372 Eh    ::
#          :: add. restraining           0.000000000000 Eh    ::
#          :: total charge              -0.000000000000 e     ::
#          :::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
#                                                    XTB Gradient Driver
#                                                   =====================
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C          -0.659954489221       -0.000008545743        0.000000552404
#                            C           0.659969540366       -0.000003588271        0.000000372341
#                            H          -1.220963089703       -0.924133144885        0.070429089883
#                            H          -1.220877951509        0.924146630586       -0.070430122284
#                            H           1.220962038247        0.924133633252       -0.070429127102
#                            H           1.220963951820       -0.924134984938        0.070429234758
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C          -0.002421011815        0.000002666314       -0.000000064957
#                            C           0.002410040281        0.000003089420       -0.000000373693
#                            H          -0.000234547741       -0.004611954520        0.000351488085
#                            H          -0.000222342226        0.004603735432       -0.000350848674
#                            H           0.000235234244        0.004611984594       -0.000351490377
#                            H           0.000232627257       -0.004609521240        0.000351289615
#
#
#     33.       -6.2710359            0.0002332                0.0098671
#
#    *** Gradient Descent converged in 34 iteration(s). ***

# %%
plt.figure(figsize=(6,4))

plt.plot(gd_iterations, gd_energies,'o-', label='Gradient descent')

plt.axis(xmin=-2, xmax=43)

plt.xlabel('Iteration')
plt.ylabel('Energy (H)')
plt.title("Gradient descent convergence")
plt.legend()
plt.tight_layout(); plt.show()
